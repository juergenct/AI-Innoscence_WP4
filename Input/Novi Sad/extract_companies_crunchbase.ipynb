# %%
import pandas as pd

# %%
df_organizations = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/CrunchBase Dump TUHH/organizations.csv')

# %%
df_organizations.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'legal_name', 'roles', 'domain', 'homepage_url',
#        'country_code', 'state_code', 'region', 'city', 'address',
#        'postal_code', 'status', 'short_description', 'category_list',
#        'category_groups_list', 'num_funding_rounds', 'total_funding_usd',
#        'total_funding', 'total_funding_currency_code', 'founded_on',
#        'last_funding_on', 'closed_on', 'employee_count', 'email', 'phone',
#        'facebook_url', 'linkedin_url', 'twitter_url', 'logo_url', 'alias1',
#        'alias2', 'alias3', 'primary_role', 'num_exits'],
#       dtype='object')

# %%
# Filter df_organizations for entries where 'country_code' is 'SRB'
df_organizations = df_organizations[df_organizations['country_code'] == "SRB"]
# Filter df_organizations for entries where 'region' or 'city' is 'Novi Sad'
df_organizations = df_organizations[df_organizations['city'] == "Novi Sad"]

# %%
df_organizations['homepage_url'].head()
# Out:
# 9713     http://www.aikongroup.com
# 11283        http://www.krediti.rs
# 24961           http://plakatt.com
# 26590      http://www.pulsar-1.com
# 42809      http://renderedtext.com
# Name: homepage_url, dtype: object

# %%
df_organizations['city'].value_counts()
# Out:
# city
# Novi Sad    217
# Name: count, dtype: int64

# %%
len(df_organizations)
# Out:
# 217

# %%
df_organizations.to_csv('crunchbase_companies_SRB_Novi_Sad.csv', index=False)

# %%
df_investors = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/CrunchBase Dump TUHH/investors.csv')

# %%
# Filter df_investors for entries where 'country_code' is 'SRB'
df_investors = df_investors[df_investors['country_code'] == "SRB"]
# Filter df_investors for entries where 'region' or 'city' is 'Novi Sad'
df_investors = df_investors[df_investors['city'] == "Novi Sad"]

# %%
len(df_investors)
# Out:
# 6

# %%
df_investors.to_csv('/home/thiesen/Documents/AI-Innoscence_Ecosystem/Input/Novi Sad/crunchbase_investors_SRB_Novi_Sad.csv', index=False)
