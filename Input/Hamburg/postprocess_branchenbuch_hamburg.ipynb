# %% [markdown]
# # 🏢 Hamburg Branchenbuch - Category Filtering Workflow
#
# ## 📋 Quick Start Guide
#
# Run cells in order:
#
# 1. **Cells 1-2**: Load Branchenbuch data (39,508 companies)
# 2. **Cells 3-4**: View all categories *(optional, for reference)*
# 3. **Cells 6-9**: Load Excel file and extract categories marked for deletion
# 4. **Cell 11**: Apply filter to dataset
# 5. **Cell 13**: Save filtered dataset to CSV
#
# ---
#
# ## 📝 Process
#
# This notebook filters the Hamburg Branchenbuch dataset by removing categories marked in your Excel file (`20_10_2025_Branchenbuch_Categories_to_be_deleted.xlsx`).
#
# The Excel file should have:
# - **Column 1**: Category names (numbers will be automatically removed)
# - **Column 2**: Mark with "x" to delete that category
#
# ---

# %%
import pandas as pd

# %%
df_hamburg_branchenbuch = pd.read_csv('hamburg_branchenbuch_companies_details_from_map_20250930_162445_with_websites.csv')

# %%
# See all unique categories (sorted alphabetically)
unique_categories = sorted(df_hamburg_branchenbuch['category'].unique())
print(f"Total unique categories: {len(unique_categories)}\n")

# Print all categories, one per line
for i, cat in enumerate(unique_categories, 1):
    print(f"{i:3d}. {cat}")
    
# Alternative: See categories with their counts
print("\n" + "="*50)
print("Categories with counts:")
print("="*50)
df_hamburg_branchenbuch['category'].value_counts()
# Out:
# Total unique categories: 554
#
#   1. AIDS Hilfe
#   2. AVGS Coaching
#   3. Abbruchunternehmen
#   4. Abendkleider
#   5. Abendschule
#   6. Abrechnungsstelle
#   7. Abschleppdienst
#   8. Accor Hotel
#   9. Adidas
#  10. Afghanisches Restaurant
#  11. Afrikanisches Restaurant
#  12. Aktenlagerung
#  13. Aktenvernichtung
#  14. Akupunktur
#  15. Alarmanlagen
#  16. Alessi
#  17. Alfa Romeo
#  18. All you can eat
#  19. Allergologe
#  20. Allgemeinmediziner / Hausarzt
#  21. Altbausanierung
#  22. Altenheime
#  23. Alternative Heilmethoden
#  24. Ambulantes OP-Zentrum
#  25. Amerikanisches Restaurant
#  26. An- und Verkauf
#  27. Angelladen
#  28. Angelverein
#  29. Anhängerverleih
#  30. Anlageimmobilie
#  31. Anlagenbau
#  32. Antiquariat
#  33. Antiquitäten
#  34. Anwalt Arbeitsrecht
#  35. Anwalt Bankrecht
#  36. Anwalt Baurecht
#  37. Anwalt Erbrecht
#  38. Anwalt Familienrecht
#  39. Anwalt Gewerblicher Rechtsschutz
#  40. Anwalt IT Recht
#  41. Anwalt Immobilienrecht
#  42. Anwalt Insolvenzrecht
#  43. Anwalt Markenrecht
#  44. Anwalt Medizinrecht
#  45. Anwalt Mietrecht
#  46. Anwalt Migrationsrecht
#  47. Anwalt Sozialrecht
#  48. Anwalt Steuerrecht
#  49. Anwalt Strafrecht
#  50. Anwalt Urheberrecht und Medienrecht
#  51. Anwalt Verkehrsrecht
#  52. Anwalt Versicherungsrecht
#  53. Anwalt Verwaltungsrecht
#  54. Anwalt Wirtschaftsrecht
#  55. Anästhesist
#  56. Apotheke
#  57. Apple
#  58. Aprilia
#  59. Arabisches Restaurant
#  60. Arbeitgeberverband
#  61. Arbeitnehmerverband / Arbeiterkammern
#  62. Arbeitsbühnenvermietung
#  63. Arbeitskleidung
#  64. Architekt
#  65. Archiv
#  66. Army Shop
#  67. Arzt
#  68. Asia Markt
#  69. Asia-Imbiss
#  70. Asiatisches Restaurant
#  71. Asphaltbeschicker
#  72. Asphaltfertiger
#  73. Astrologie
#  74. Atemtherapie
#  75. Audi
#  76. Auktionshaus
#  77. Ausbildung
#  78. Ausflugslokale
#  79. Australisches Restaurant
#  80. Auto & Verkehr
#  81. Autobahnraststätte
#  82. Autoelektriker
#  83. Autogas
#  84. Autoglaser
#  85. Autohändler
#  86. Autolackierer
#  87. Automatenaufsteller
#  88. Autosattlerei
#  89. Autovermietung
#  90. Außenwerbung / Lichtwerbung
#  91. Baby
#  92. Bademode
#  93. Badminton
#  94. Badmöbel
#  95. Badsanierung
#  96. Balkan Restaurant
#  97. Ballett
#  98. Ballonfahrt
#  99. Band
# 100. Banken
# 101. Banken / Sparkassen
# 102. Bar
# 103. Barbershop
# 104. Baseball
# 105. Basketball
# 106. Baubedarf / Heimwerkerbedarf / Baustoffe
# 107. Bauberatung
# 108. Baudienstleistungen
# 109. Bauelemente / Baustoffe
# 110. Bauen & Wohnen
# 111. Baufinanzierung
# 112. Baugewerbe
# 113. Bauhandwerk
# 114. Baumarkt
# 115. Baumaschinenvermietung
# 116. Baumpflege
# 117. Baumschule
# 118. Bausachverständiger
# 119. Bausparkasse
# 120. Bauträger
# 121. Bauunternehmen
# 122. Bauunternehmen Hoch/Tief
# 123. Bayrisches Restaurant
# 124. Beachclub
# 125. Behinderteneinrichtung
# 126. Behindertensport
# 127. Behindertentransport
# 128. Behindertenwerkstatt
# 129. Beratender Ingenieur
# 130. Beratung
# 131. Berufsbekleidung
# 132. Berufsberatung
# 133. Berufsfachschule
# 134. Berufsverband
# 135. Beschriftung & Folientechnik
# 136. Bestatter
# 137. Beteiligungsgesellschaft
# 138. Betreutes Wohnen
# 139. Betriebsarzt
# 140. Betten
# 141. Bettwäsche
# 142. Biergarten
# 143. Bildagentur
# 144. Bilderrahmen
# 145. Bildhauer
# 146. Bildung & Wissen
# 147. Billard
# 148. Bio Produkte
# 149. Bio Restaurant
# 150. Biokiste
# 151. Bioladen
# 152. Biotechnologie
# 153. Birkenstock
# 154. Bistro
# 155. Blechwaren
# 156. Blitzschutz
# 157. Blockheizkraftwerk
# 158. Blumenladen
# 159. Blutspende
# 160. Boardinghouse
# 161. Bodega
# 162. Bodenbeläge
# 163. Bodengutachten
# 164. Bodenleger
# 165. Bogner
# 166. Boote / Schiffsausrüster
# 167. Bootshaus
# 168. Bootsliegeplatz
# 169. Bootsverleih
# 170. Bordparty
# 171. Boutique
# 172. Bowling
# 173. Boxen
# 174. Boxspringbett
# 175. Brandmeldeanlagen
# 176. Brandschutz
# 177. Brasilianisches Restaurant
# 178. Brauerei
# 179. Brauhaus
# 180. Brautmode
# 181. Briefmarken
# 182. Brunch
# 183. Bubbletea
# 184. Buchbinder
# 185. Buchhaltung
# 186. Buchhandlung
# 187. Bundesverband
# 188. Burger
# 189. Business Center
# 190. Busreisen
# 191. Busvermietung
# 192. Bäckerei
# 193. Bäderland
# 194. Börse / Börsenmakler
# 195. Bündnis 90 / Die Grünen GAL
# 196. Bürgerhaus
# 197. Bürgerverein
# 198. Büro mieten
# 199. Bürobedarf / Schreibwaren
# 200. Büroeinrichtung
# 201. Büromöbel
# 202. Büroreinigung
# 203. Büroservice
# 204. CD / DVD
# 205. CDU
# 206. Café
# 207. Call-Center
# 208. Call-Shop
# 209. Camel active
# 210. Campingplatz
# 211. Campingzubehör
# 212. Canon
# 213. Car HiFi
# 214. Casino
# 215. Casting Agentur
# 216. Catering
# 217. Chemie Handel
# 218. Chemische Reinigung
# 219. China Restaurant
# 220. Citizen
# 221. Club
# 222. Coaching
# 223. Cocktailbar
# 224. Coffee Shop
# 225. Comicladen
# 226. Computer
# 227. Computerkurse
# 228. Computerzubehör
# 229. Consulting
# 230. Container
# 231. Copyshop
# 232. Corsage
# 233. Coworking
# 234. Croque
# 235. Currywurst
# 236. DJ
# 237. DRK
# 238. Damenmode
# 239. Dart
# 240. Datenrettung
# 241. Datenschutz
# 242. Deko
# 243. Demenzbetreuung
# 244. Dentallabor
# 245. Designagentur
# 246. Designer
# 247. Designermode
# 248. Designermöbel
# 249. Dessous
# 250. Detektei / Detektiv
# 251. Deutsche Küche
# 252. Diabetesberatung
# 253. Dialogmarketing
# 254. Dialyse
# 255. Die Linke
# 256. Digitaldruck
# 257. Digitalisierung
# 258. Disco / Musik Club
# 259. Dolmetscher und Übersetzer
# 260. Donuts
# 261. Drechsler
# 262. Dreherei
# 263. Drogerie
# 264. Druck / Fotokopie
# 265. Döner
# 266. E-Commerce
# 267. E-Zigaretten
# 268. EDV-Beratung / Software
# 269. Einbruchschutz
# 270. Einkaufszentrum
# 271. Eishockey
# 272. Elektriker
# 273. Elektrische Anlagen
# 274. Elektrobedarf
# 275. Elektrogeräte
# 276. Elektronisches
# 277. Elektrotechnik / Elektronik
# 278. Elektrowerkzeuge
# 279. Endodontie
# 280. Energie / Wasser
# 281. Entsorgung
# 282. Ergotherapie
# 283. Erlebnisgastronomie
# 284. Erneuerbare Energien
# 285. Erotik
# 286. Erotikmassage
# 287. Erziehungsberatung
# 288. Escape Game
# 289. Escort
# 290. Esoterik
# 291. Esprit
# 292. Essen & Trinken
# 293. Essen auf Rädern
# 294. Evangelische Kirche / Katholische Kirche
# 295. Eventagentur
# 296. Eventlocation
# 297. Existenzgründung
# 298. FDP
# 299. FKK
# 300. Fahrradladen
# 301. Fahrradverleih
# 302. Faltdisplays
# 303. Fassadenreinigung
# 304. Fast Food
# 305. Fechten
# 306. Feinkost
# 307. Feng-Shui
# 308. Fensterputzer
# 309. Ferienwohnung
# 310. Fernsehindustrie / Filmindustrie
# 311. Fernsehreparatur
# 312. Feuerlöschtechnik
# 313. Feuerwehr
# 314. Feuerwerk
# 315. Filmproduktion
# 316. Filmstudio
# 317. Finanzberater
# 318. Fischladen
# 319. Fitnessshop
# 320. Fitnessstudio
# 321. Fluggesellschaften
# 322. Flughafentransfer
# 323. Flugschule
# 324. Football
# 325. Forschung
# 326. Fossil
# 327. Foto
# 328. Franchise
# 329. Freiberufler
# 330. Freie Redner
# 331. Freizeitanlage
# 332. Freizeitpark
# 333. Friedhof
# 334. Friseur
# 335. Friseurbedarf
# 336. Fräszentrum
# 337. Funkgeräte
# 338. Fußball
# 339. Fußballstadion
# 340. Fußpflege
# 341. Gabelstapler
# 342. Galabau
# 343. Galerie
# 344. Gardinenreinigung
# 345. Garten- und Landschaftsbau
# 346. Gartenbedarf
# 347. Gartengeräte
# 348. Gartenmöbel
# 349. Gastronomiebedarf
# 350. Gebäudereinigung
# 351. Geocaching
# 352. Gesangsunterricht
# 353. Geschenke
# 354. Gesellschaft & Soziales
# 355. Gesundheit & Medizin
# 356. Gesundheitswesen
# 357. Getränke
# 358. Gewerbeimmobilien
# 359. Gewürze / Kräuter
# 360. Glas / Keramik / Porzellan
# 361. Glasnotdienst
# 362. Gold / Edelmetall
# 363. Goldankauf
# 364. Goldschmied / Silberschmied
# 365. Golf
# 366. Grafik / Design / Fotografie
# 367. Grafikdesign
# 368. Gravuren
# 369. Großhandel & Vertriebsunternehmen
# 370. Großhandel Bürobedarf
# 371. Großhandel Möbel / Haushaltsgegenstände
# 372. Grundeigentümerverband
# 373. Grundschule
# 374. Gymnastik
# 375. Gärtnerei
# 376. Haarentfernung / Waxing
# 377. Hafenrundfahrt
# 378. Halteverbot
# 379. Hamam
# 380. Handarbeiten
# 381. Handball
# 382. Handel & Shopping
# 383. Handschuhe
# 384. Handwerk
# 385. Handwerker
# 386. Handyreparatur
# 387. Haushaltsauflösung / Entrümpelung
# 388. Haushaltshilfe
# 389. Hausnotruf
# 390. Hausverwaltung / Grundstücksverwaltung
# 391. Headhunter
# 392. Heißmangel
# 393. Hersteller & Industrie
# 394. Hersteller Baubedarf
# 395. Hersteller Chemieindustrie
# 396. Hersteller Luftfahrzeuge
# 397. Hersteller Ökologie / Umwelttechnik
# 398. Hilf Mahl !
# 399. Hochseilgarten
# 400. Hochzeit
# 401. Hochzeitsplaner
# 402. Hostel / Jugendherberge
# 403. Hotel
# 404. Hotel Garni
# 405. Hundebetreuung
# 406. Hundefriseur
# 407. Hundepension
# 408. Hundeschule
# 409. Hundezucht
# 410. Hüpfburg
# 411. IT-Service
# 412. Immobilienberatung
# 413. Immobilienmakler
# 414. Implantologie
# 415. Import / Export Kfz-Ersatzteile / Kfz-Zubehör
# 416. Indoorspielplatz
# 417. Informationsdienst
# 418. Ingenieur Energietechnik / Umwelttechnik
# 419. Ingenieurbüro
# 420. Inkasso
# 421. Inneneinrichtung
# 422. Insolvenzverwalter
# 423. Internetagentur
# 424. Internetcafe
# 425. Internetprovider
# 426. Investmentgesellschaften
# 427. Italienische Lebensmittel
# 428. JGA
# 429. Journalist / Redakteur
# 430. Kabarett / Comedy
# 431. Kampfsport
# 432. Kanuverleih
# 433. Kartbahn
# 434. Kartenvorverkauf
# 435. Katzenpension
# 436. Katzensitter
# 437. Kegeln
# 438. Keramik bemalen
# 439. Kinder / Jugendliche
# 440. Kinderaktivitäten
# 441. Kinderbauernhof
# 442. Kindergeburtstag
# 443. Kindertheater
# 444. Kino
# 445. Klavier / Piano
# 446. Klettern
# 447. Konferenzraum
# 448. Konferenztechnik
# 449. Konzertagentur / Künstleragentur
# 450. Konzerthaus / Orchester
# 451. Kosmetikstudio
# 452. Kostümbildner / Maskenbildner
# 453. Kostümverleih
# 454. Kran und Kranverleih
# 455. Kreuzfahrt
# 456. Kulturelle Einrichtungen
# 457. Kundendienst Haushaltsgeräte
# 458. Kunst / Kultur
# 459. Küchenstudio
# 460. Künstler
# 461. Labor
# 462. Lagerhaus
# 463. Lagerraum mieten
# 464. Lagerung
# 465. Lampen
# 466. Lasertag
# 467. Leasing
# 468. Lektorat
# 469. Lesezirkel
# 470. Lohnsteuerhilfe
# 471. Lotto
# 472. Makler
# 473. Marketing / Werbung / PR
# 474. Marketingberatung
# 475. Marktforschung
# 476. Maschinenbau
# 477. Massage
# 478. Matratzenreinigung
# 479. Maßschneider
# 480. Mediation
# 481. Messebau
# 482. Minigolf
# 483. Modelagentur
# 484. Motel
# 485. Musiker
# 486. Musikinstrument Reparatur / Stimmer
# 487. Musikproduzent
# 488. Musikschule
# 489. Musikverlag
# 490. Nagelstudio
# 491. Notar
# 492. Nähkurs
# 493. Online Spiele
# 494. Online-Portal
# 495. Padel
# 496. Paintball
# 497. Paketshop
# 498. Partnervermittlung
# 499. Partyservice
# 500. Permanent Make-up
# 501. Personal Trainer
# 502. Personalberatung
# 503. Personalvermittlung
# 504. Personenschutz
# 505. Pflegedienst
# 506. Piercing
# 507. Pilates
# 508. Planungsbüro
# 509. Polsterreinigung
# 510. Ponyreiten
# 511. Pop Up-Store mieten
# 512. Portraitmaler
# 513. Post
# 514. Postfiliale
# 515. Premium Partner
# 516. Premium Partner Dienstleistung
# 517. Premium Partner Essen & Trinken
# 518. Presse
# 519. Pumpen-Reparatur
# 520. Qigong
# 521. Qualitätsmanagement
# 522. Recht & Geld
# 523. Rechtsanwalt
# 524. Redaktion
# 525. Reinigungsunternehmen
# 526. Reise & Übernachtung
# 527. Reiten
# 528. Reiterhof
# 529. Reitstall
# 530. Relocation Service
# 531. Restaurant
# 532. Rückenschule
# 533. Schauspieler
# 534. Schlittschuhbahn
# 535. Schreibbüro
# 536. Schwimmbad
# 537. Schwimmen
# 538. Schädlingsbekämpfung
# 539. Schönheit & Wellness
# 540. Segelschule
# 541. Seminarraum
# 542. Service & Dienstleistung
# 543. Sicherheitstechnik
# 544. Spielhalle
# 545. Sport & Freizeit
# 546. Sporthalle
# 547. Stadtführung
# 548. Tanzen
# 549. Tanzschule
# 550. Verlag
# 551. Änderungsschneiderei
# 552. Ökologie- und Umwelttechnik
# 553. Ökologisch orientierte Unternehmen
# 554. Übersicht Vermietung und Verleih
#
# ==================================================
# Categories with counts:
# ==================================================
# category
# Handel & Shopping          3062
# Auto & Verkehr             2558
# Gesellschaft & Soziales    1963
# Arzt                       1906
# Gesundheit & Medizin       1731
#                            ...
# Ballonfahrt                   1
# Musikschule                   1
# Nähkurs                       1
# Inneneinrichtung              1
# Stadtführung                  1
# Name: count, Length: 554, dtype: int64

# %% [markdown]
# ---
#
# ## 📂 Step 1: Load Categories from Excel File
#
# Load the categories marked for deletion from `20_10_2025_Branchenbuch_Categories_to_be_deleted.xlsx`

# %%
import re

# Read the deletion list from Excel/CSV
deletion_file = '20_10_2025_Branchenbuch_Categories_to_be_deleted.xlsx'

# Try reading as Excel first, if that fails, try CSV
try:
    df_deletion = pd.read_excel(deletion_file, header=0)
    print("✅ Loaded Excel file")
except:
    # Try CSV with semicolon separator
    df_deletion = pd.read_csv(deletion_file.replace('.xlsx', '.csv'), sep=';', header=0)
    print("✅ Loaded CSV file")

print(f"Loaded {len(df_deletion)} rows\n")
print("First few rows:")
print(df_deletion.head(10))
# Out:
# ✅ Loaded Excel file
# Loaded 554 rows
#
# First few rows:
#   Total unique categories: 554 1 To be deleted
# 0                   AIDS Hilfe 2             x
# 1                AVGS Coaching 3             x
# 2           Abbruchunternehmen 4           NaN
# 3                 Abendkleider 5             x
# 4                  Abendschule 6             x
# 5            Abrechnungsstelle 7             x
# 6              Abschleppdienst 8             x
# 7                  Accor Hotel 9             x
# 8                      Adidas 10             x
# 9     Afghanisches Restaurant 11             x

# %%
# Extract categories marked for deletion
# Column 1: Category name with trailing number (e.g., " AIDS Hilfe 2")
# Column 2: "x" marks categories to delete

# Get column names
col_category = df_deletion.columns[0]  # First column
col_to_delete = df_deletion.columns[1]  # Second column

print(f"Category column: '{col_category}'")
print(f"Deletion marker column: '{col_to_delete}'")
print()

# Filter rows where second column contains 'x'
df_marked_for_deletion = df_deletion[df_deletion[col_to_delete].astype(str).str.lower() == 'x'].copy()

print(f"Found {len(df_marked_for_deletion)} categories marked for deletion\n")

# Clean the category names: remove trailing numbers (e.g., " AIDS Hilfe 2" -> "AIDS Hilfe")
def clean_category_name(cat_str):
    """Remove leading/trailing spaces and trailing numbers from category names"""
    if pd.isna(cat_str):
        return ""
    
    # Convert to string and strip whitespace
    cat_str = str(cat_str).strip()
    
    # Remove trailing pattern like " 2", " 123", etc.
    # Pattern: optional space + one or more digits at the end
    cat_str = re.sub(r'\s+\d+$', '', cat_str)
    
    return cat_str

df_marked_for_deletion['cleaned_category'] = df_marked_for_deletion[col_category].apply(clean_category_name)

# Create the list of categories to remove
categories_to_remove = df_marked_for_deletion['cleaned_category'].tolist()

# Remove any empty strings
categories_to_remove = [cat for cat in categories_to_remove if cat]

print(f"✅ Extracted {len(categories_to_remove)} categories to remove\n")
print("First 20 categories to be removed:")
for i, cat in enumerate(categories_to_remove[:20], 1):
    count = len(df_hamburg_branchenbuch[df_hamburg_branchenbuch['category'] == cat])
    if count > 0:
        print(f"  {i:2d}. {cat} ({count:,} companies)")
    else:
        print(f"  {i:2d}. {cat} ⚠️ NOT FOUND in dataset")
# Out:
# Category column: 'Total unique categories: 554 1'
# Deletion marker column: 'To be deleted'
#
# Found 466 categories marked for deletion
#
# ✅ Extracted 466 categories to remove
#
# First 20 categories to be removed:
#    1. AIDS Hilfe (4 companies)
#    2. AVGS Coaching (24 companies)
#    3. Abendkleider (43 companies)
#    4. Abendschule (2 companies)
#    5. Abrechnungsstelle (13 companies)
#    6. Abschleppdienst (4 companies)
#    7. Accor Hotel (11 companies)
#    8. Adidas (8 companies)
#    9. Afghanisches Restaurant (5 companies)
#   10. Afrikanisches Restaurant (3 companies)
#   11. Aktenlagerung (4 companies)
#   12. Aktenvernichtung (4 companies)
#   13. Akupunktur (39 companies)
#   14. Alarmanlagen (35 companies)
#   15. Alessi (7 companies)
#   16. Alfa Romeo (4 companies)
#   17. All you can eat (6 companies)
#   18. Allergologe (3 companies)
#   19. Allgemeinmediziner / Hausarzt (1 companies)
#   20. Altenheime (73 companies)

# %%
# Verify: Show summary statistics
print("=" * 70)
print("SUMMARY OF CATEGORIES TO REMOVE")
print("=" * 70)

total_companies_to_remove = 0
categories_found = []
categories_not_found = []

for cat in categories_to_remove:
    count = len(df_hamburg_branchenbuch[df_hamburg_branchenbuch['category'] == cat])
    if count > 0:
        categories_found.append((cat, count))
        total_companies_to_remove += count
    else:
        categories_not_found.append(cat)

print(f"✅ Categories found in dataset: {len(categories_found)}")
print(f"⚠️  Categories NOT found: {len(categories_not_found)}")
print(f"📊 Total companies to be removed: {total_companies_to_remove:,}")
print(f"📊 Percentage of dataset: {total_companies_to_remove/len(df_hamburg_branchenbuch)*100:.1f}%")

if categories_not_found:
    print(f"\n⚠️  Categories not found in dataset (typos?):")
    for cat in categories_not_found[:10]:  # Show first 10
        print(f"   - '{cat}'")
# Out:
# ======================================================================
# SUMMARY OF CATEGORIES TO REMOVE
# ======================================================================
# ✅ Categories found in dataset: 466
# ⚠️  Categories NOT found: 0
# 📊 Total companies to be removed: 28,529
# 📊 Percentage of dataset: 72.2%

# %%
# OPTIONAL: Show ALL categories that will be removed (sorted by company count)
print("=" * 70)
print("ALL CATEGORIES TO BE REMOVED (sorted by number of companies)")
print("=" * 70)

categories_sorted = sorted(categories_found, key=lambda x: x[1], reverse=True)

for i, (cat, count) in enumerate(categories_sorted, 1):
    print(f"{i:3d}. {cat:50s} {count:5,} companies")

print()
print(f"Total: {len(categories_sorted)} categories, {total_companies_to_remove:,} companies")
# Out:
# ======================================================================
# ALL CATEGORIES TO BE REMOVED (sorted by number of companies)
# ======================================================================
#   1. Handel & Shopping                                  3,062 companies
#   2. Gesellschaft & Soziales                            1,963 companies
#   3. Arzt                                               1,906 companies
#   4. Gesundheit & Medizin                               1,731 companies
#   5. Service & Dienstleistung                           1,616 companies
#   6. Essen & Trinken                                    1,571 companies
#   7. Alternative Heilmethoden                             968 companies
#   8. Grafik / Design / Fotografie                         575 companies
#   9. Reise & Übernachtung                                 564 companies
#  10. EDV-Beratung / Software                              399 companies
#  11. Bäckerei                                             397 companies
#  12. Friseur                                              323 companies
#  13. Marketingberatung                                    306 companies
#  14. Endodontie                                           281 companies
#  15. Damenmode                                            280 companies
#  16. Apotheke                                             272 companies
#  17. Marketing / Werbung / PR                             271 companies
#  18. Sport & Freizeit                                     263 companies
#  19. Hotel                                                260 companies
#  20. Fitnessstudio                                        259 companies
#  21. Café                                                 258 companies
#  22. Filmproduktion                                       257 companies
#  23. Bar                                                  230 companies
#  24. Handwerk                                             218 companies
#  25. Druck / Fotokopie                                    200 companies
#  26. Computer                                             192 companies
#  27. Schönheit & Wellness                                 188 companies
#  28. Designagentur                                        187 companies
# 194. Beschriftung & Folientechnik                          15 companies
# 195. Fensterputzer                                         15 companies
# 196. Journalist / Redakteur                                15 companies
# 197. Boxen                                                 14 companies
# 198. Designermode                                          14 companies
# 199. Lektorat                                              14 companies
# 200. Abrechnungsstelle                                     13 companies
# 201. Anwalt Medizinrecht                                   13 companies
# 202. Chemische Reinigung                                   13 companies
# 203. Feng-Shui                                             13 companies
# 204. Fußball                                               13 companies
# 205. Golf                                                  13 companies
# 206. Handball                                              13 companies
# 207. Informationsdienst                                    13 companies
# 208. Angelverein                                           12 companies
# 209. Autosattlerei                                         12 companies
# 210. Headhunter                                            12 companies
# 211. Hochzeitsplaner                                       12 companies
# 212. Musikproduzent                                        12 companies
# 213. Musikverlag                                           12 companies
# 214. Relocation Service                                    12 companies
# 215. Accor Hotel                                           11 companies
# 216. Anwalt Bankrecht                                      11 companies
# 217. Call-Center                                           11 companies
# 218. Currywurst                                            11 companies
# 219. Balkan Restaurant                                     10 companies
# 220. Basketball                                            10 companies
# 221. Briefmarken                                           10 companies
# 222. Busreisen                                             10 companies
# 223. Disco / Musik Club                                    10 companies
# 224. Escape Game                                           10 companies
# 225. Gardinenreinigung                                     10 companies
# 226. Gartenmöbel                                           10 companies
# 227. Gravuren                                              10 companies
# 228. Inkasso                                               10 companies
# 229. Kampfsport                                            10 companies
# 230. Mediation                                             10 companies
# 231. Modelagentur                                          10 companies
# 232. Musiker                                               10 companies
# 233. Baumschule                                             9 companies
# 234. Chemie Handel                                          9 companies
# 235. Fitnessshop                                            9 companies
# 236. Reinigungsunternehmen                                  9 companies
# 237. Spielhalle                                             9 companies
# 238. Adidas                                                 8 companies
# 239. Anwalt Migrationsrecht                                 8 companies
# 240. Asia Markt                                             8 companies
# 241. Autoglaser                                             8 companies
# 242. Berufsberatung                                         8 companies
# 243. Bodenleger                                             8 companies
# 244. Croque                                                 8 companies
# 245. Gebäudereinigung                                       8 companies
# 246. Handarbeiten                                           8 companies
# 247. Kostümbildner / Maskenbildner                          8 companies
# 248. Lotto                                                  8 companies
# 249. Alessi                                                 7 companies
# 250. Automatenaufsteller                                    7 companies
# 251. Brauerei                                               7 companies
# 252. Comicladen                                             7 companies
# 253. Erlebnisgastronomie                                    7 companies
# 254. Erotikmassage                                          7 companies
# 255. Kabarett / Comedy                                      7 companies
# 256. Kindertheater                                          7 companies
# 257. Leasing                                                7 companies
# 258. Qigong                                                 7 companies
# 259. All you can eat                                        6 companies
# 260. Anhängerverleih                                        6 companies
# 261. Anwalt Steuerrecht                                     6 companies
# 262. Aprilia                                                6 companies
# 263. Astrologie                                             6 companies
# 264. Bettwäsche                                             6 companies
# 265. Bootsverleih                                           6 companies
# 266. Bowling                                                6 companies
# 267. Brandmeldeanlagen                                      6 companies
# 268. Casting Agentur                                        6 companies
# 269. Datenschutz                                            6 companies
# 270. Einbruchschutz                                         6 companies
# 271. Esoterik                                               6 companies
# 272. Filmstudio                                             6 companies
# 273. Flugschule                                             6 companies
# 274. Hundefriseur                                           6 companies
# 275. Konzerthaus / Orchester                                6 companies
# 276. Lagerhaus                                              6 companies
# 277. Reitstall                                              6 companies
# 278. Seminarraum                                            6 companies
# 279. Afghanisches Restaurant                                5 companies
# 280. An- und Verkauf                                        5 companies
# 281. Anwalt Verwaltungsrecht                                5 companies
# 282. Arabisches Restaurant                                  5 companies
# 283. Arbeitsbühnenvermietung                                5 companies
# 284. Army Shop                                              5 companies
# 285. Beachclub                                              5 companies
# 286. Büroeinrichtung                                        5 companies
# 287. Cocktailbar                                            5 companies
# 288. Computerzubehör                                        5 companies
# 289. Datenrettung                                           5 companies
# 290. Donuts                                                 5 companies
# 291. FKK                                                    5 companies
# 292. Fahrradverleih                                         5 companies
# 293. Gabelstapler                                           5 companies
# 294. Gymnastik                                              5 companies
# 295. Online Spiele                                          5 companies
# 296. Partnervermittlung                                     5 companies
# 297. Permanent Make-up                                      5 companies
# 298. Personenschutz                                         5 companies
# 299. AIDS Hilfe                                             4 companies
# 300. Abschleppdienst                                        4 companies
# 301. Aktenlagerung                                          4 companies
# 302. Aktenvernichtung                                       4 companies
# 303. Alfa Romeo                                             4 companies
# 304. Anwalt IT Recht                                        4 companies
# 305. Anwalt Versicherungsrecht                              4 companies
# 306. Behindertentransport                                   4 companies
# 307. Betriebsarzt                                           4 companies
# 308. Bootshaus                                              4 companies
# 309. Bootsliegeplatz                                        4 companies
# 310. Brasilianisches Restaurant                             4 companies
# 311. Bubbletea                                              4 companies
# 312. Buchbinder                                             4 companies
# 313. Casino                                                 4 companies
# 314. Demenzbetreuung                                        4 companies
# 315. Essen auf Rädern                                       4 companies
# 316. Faltdisplays                                           4 companies
# 317. Fechten                                                4 companies
# 318. Feuerwerk                                              4 companies
# 319. Freizeitpark                                           4 companies
# 320. Friseurbedarf                                          4 companies
# 321. Heißmangel                                             4 companies
# 322. Hotel Garni                                            4 companies
# 323. Indoorspielplatz                                       4 companies
# 324. Internetcafe                                           4 companies
# 325. Kartenvorverkauf                                       4 companies
# 326. Konferenzraum                                          4 companies
# 327. Lohnsteuerhilfe                                        4 companies
# 328. Pop Up-Store mieten                                    4 companies
# 329. Post                                                   4 companies
# 330. Premium Partner Dienstleistung                         4 companies
# 331. Schreibbüro                                            4 companies
# 332. Schwimmen                                              4 companies
# 333. Segelschule                                            4 companies
# 334. Tanzen                                                 4 companies
# 335. Afrikanisches Restaurant                               3 companies
# 336. Allergologe                                            3 companies
# 337. Arbeitgeberverband                                     3 companies
# 338. Autoelektriker                                         3 companies
# 339. Autolackierer                                          3 companies
# 340. Behindertenwerkstatt                                   3 companies
# 341. Birkenstock                                            3 companies
# 342. Blitzschutz                                            3 companies
# 343. Bodengutachten                                         3 companies
# 344. Boxspringbett                                          3 companies
# 345. Busvermietung                                          3 companies
# 346. Campingplatz                                           3 companies
# 347. Computerkurse                                          3 companies
# 348. Corsage                                                3 companies
# 349. Dreherei                                               3 companies
# 350. Eishockey                                              3 companies
# 351. Fernsehreparatur                                       3 companies
# 352. Feuerlöschtechnik                                      3 companies
# 353. Franchise                                              3 companies
# 354. Freiberufler                                           3 companies
# 355. Gold / Edelmetall                                      3 companies
# 356. Hüpfburg                                               3 companies
# 357. Katzensitter                                           3 companies
# 438. Import / Export Kfz-Ersatzteile / Kfz-Zubehör          1 companies
# 439. Inneneinrichtung                                       1 companies
# 440. Italienische Lebensmittel                              1 companies
# 441. JGA                                                    1 companies
# 442. Kanuverleih                                            1 companies
# 443. Kartbahn                                               1 companies
# 444. Kegeln                                                 1 companies
# 445. Kinder / Jugendliche                                   1 companies
# 446. Klavier / Piano                                        1 companies
# 447. Klettern                                               1 companies
# 448. Kran und Kranverleih                                   1 companies
# 449. Küchenstudio                                           1 companies
# 450. Lagerraum mieten                                       1 companies
# 451. Lampen                                                 1 companies
# 452. Lesezirkel                                             1 companies
# 453. Motel                                                  1 companies
# 454. Musikschule                                            1 companies
# 455. Nähkurs                                                1 companies
# 456. Pflegedienst                                           1 companies
# 457. Postfiliale                                            1 companies
# 458. Premium Partner                                        1 companies
# 459. Premium Partner Essen & Trinken                        1 companies
# 460. Restaurant                                             1 companies
# 461. Rückenschule                                           1 companies
# 462. Schauspieler                                           1 companies
# 463. Schädlingsbekämpfung                                   1 companies
# 464. Sicherheitstechnik                                     1 companies
# 465. Stadtführung                                           1 companies
# 466. Verlag                                                 1 companies
#
# Total: 466 categories, 28,529 companies

# %% [markdown]
# ---
#
# ## 📊 Step 2: Filter the Dataset
#
# Apply the filter using the categories loaded from Excel.

# %%
# Show statistics BEFORE filtering
print("=" * 60)
print("BEFORE FILTERING:")
print("=" * 60)
print(f"Total companies: {len(df_hamburg_branchenbuch):,}")
print(f"Total categories: {df_hamburg_branchenbuch['category'].nunique()}")
print()

# Filter: Keep only rows where category is NOT in the removal list
df_filtered = df_hamburg_branchenbuch[~df_hamburg_branchenbuch['category'].isin(categories_to_remove)].copy()

# Show statistics AFTER filtering
print("=" * 60)
print("AFTER FILTERING:")
print("=" * 60)
print(f"Total companies: {len(df_filtered):,}")
print(f"Total categories: {df_filtered['category'].nunique()}")
print()

# Show what was removed
companies_removed = len(df_hamburg_branchenbuch) - len(df_filtered)
print("=" * 60)
print("SUMMARY:")
print("=" * 60)
print(f"✅ Companies removed: {companies_removed:,} ({companies_removed/len(df_hamburg_branchenbuch)*100:.1f}%)")
print(f"✅ Companies remaining: {len(df_filtered):,} ({len(df_filtered)/len(df_hamburg_branchenbuch)*100:.1f}%)")
print(f"✅ Categories removed: {len(categories_to_remove)}")
# Out:
# ============================================================
# BEFORE FILTERING:
# ============================================================
# Total companies: 39,507
# Total categories: 554
#
# ============================================================
# AFTER FILTERING:
# ============================================================
# Total companies: 10,978
# Total categories: 88
#
# ============================================================
# SUMMARY:
# ============================================================
# ✅ Companies removed: 28,529 (72.2%)
# ✅ Companies remaining: 10,978 (27.8%)
# ✅ Categories removed: 466

# %% [markdown]
# ---
#
# ## 💾 Step 3: Save the Filtered Dataset

# %%
# Save the filtered dataset
output_filename = 'hamburg_branchenbuch_filtered_categories.csv'
df_filtered.to_csv(output_filename, index=False)
print(f"✅ Filtered dataset saved to: {output_filename}")
print(f"   {len(df_filtered):,} companies across {df_filtered['category'].nunique()} categories")
# Out:
# ✅ Filtered dataset saved to: hamburg_branchenbuch_filtered_categories.csv
#    10,978 companies across 88 categories
