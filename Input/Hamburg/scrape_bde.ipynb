# %% [markdown]
# # BDE Fördermitglieder – Partner-Links extrahieren
#
# Dieses Notebook lädt die Übersichtsseite der BDE-Fördermitglieder, extrahiert alle Partner-Links (sowohl interne Profilseiten als auch die extern verlinkten "Weitere Partner") und speichert sie als CSV.
#
# - Quelle: https://www.bde.de/verband/mitgliedschaft/foerdermitglieder/
# - Ausgabe: data/bde_foerdermitglieder.csv
#
# Hinweise:
# - Einige Logos sind als reine Bilder ohne sichtbaren Text hinterlegt. In diesen Fällen werden Name/Bezeichnung über das `alt`-Attribut, `title`, `aria-label` oder notfalls den Titel der verlinkten Unterseite (H1) bestimmt.
# - Doppelte Einträge (z. B. gleiche URL in mehreren Sektionen) werden dedupliziert.

# %%
import re
import time
import pathlib
from urllib.parse import urljoin, urlparse

import requests
from bs4 import BeautifulSoup
import pandas as pd

BASE_URL = "https://www.bde.de/verband/mitgliedschaft/foerdermitglieder/"
OUTPUT_DIR = pathlib.Path("data")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
OUTPUT_FILE = OUTPUT_DIR / "bde_foerdermitglieder.csv"

headers = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0 Safari/537.36",
}

session = requests.Session()
session.headers.update(headers)

resp = session.get(BASE_URL, timeout=30)
resp.raise_for_status()
soup = BeautifulSoup(resp.text, "lxml")

# Helper functions

def clean_text(s: str | None) -> str:
    if not s:
        return ""
    s = re.sub(r"\s+", " ", s)
    return s.strip()


def best_label_from_anchor(a):
    # Prefer visible text
    txt = clean_text(a.get_text(" "))
    if txt:
        return txt
    # Fallback to attributes
    for attr in ("title", "aria-label"):
        v = clean_text(a.get(attr))
        if v:
            return v
    # Look for image alt inside anchor
    img = a.find("img")
    if img:
        for attr in ("alt", "title"):
            v = clean_text(img.get(attr))
            if v:
                return v
    return ""


def combine_following_content(heading_tag):
    # Combines sibling blocks until next h2/h3
    blocks = []
    for sib in heading_tag.next_siblings:
        if getattr(sib, "name", None) in ("h2", "h3"):
            break
        if getattr(sib, "name", None) in ("div", "section", "p", "ul", "ol"):
            blocks.append(sib)
    if blocks:
        return BeautifulSoup("".join(str(x) for x in blocks), "lxml")
    # Fallback to parent
    return heading_tag.parent if heading_tag.parent else soup


SOCIAL_DOMAINS = {
    "linkedin.com", "facebook.com", "twitter.com", "x.com", "youtube.com", "instagram.com",
    "xing.com", "kununu.com", "google.com", "goo.gl", "bit.ly", "t.me"
}


def is_social_url(url: str) -> bool:
    netloc = urlparse(url).netloc.lower()
    return any(dom in netloc for dom in SOCIAL_DOMAINS)


def find_external_website_on_profile(profile_url: str) -> tuple[str | None, str | None]:
    """Return (company_name, website_url) from a BDE profile page."""
    try:
        r = session.get(profile_url, timeout=30)
        if not r.ok:
            return None, None
        psoup = BeautifulSoup(r.text, "lxml")
        # Name from H1/H2
        name = None
        h = psoup.find(["h1", "h2"])  # don't require string-only
        if h:
            name = clean_text(h.get_text()) or None

        # Look for explicit external website anchors
        candidates = []
        for a in psoup.select("a[href]"):
            href = a.get("href")
            if not href:
                continue
            u = urljoin(profile_url, href)
            if "bde.de" in urlparse(u).netloc.lower():
                continue
            if is_social_url(u):
                continue
            label = best_label_from_anchor(a)
            # Score candidates: prefer those that look like a domain label (contains a dot) or have globe/WWW text
            score = 0
            if re.search(r"([a-z0-9-]+\.)+[a-z]{2,}", (label or "") + " " + u, re.I):
                score += 2
            if any(t in (label or "").lower() for t in ["www", "website", "webseite", "homepage", "zur website", "mehr infos", "informationen"]):
                score += 1
            # If a nearby section mentions "Weitere Informationen", reward similar anchors
            if psoup.find(string=re.compile("Weitere Informationen", re.I)) and re.search(r"information", (label or ""), re.I):
                score += 1
            candidates.append((score, u))
        if candidates:
            candidates.sort(key=lambda x: x[0], reverse=True)
            website = candidates[0][1]
            return name, website
        return name, None
    except Exception:
        return None, None


# Identify sections by headings
headings = soup.find_all(["h2", "h3"])  # allow nested spans, etc.
unsere_blocks = []
weitere_blocks = []
for h in headings:
    title = clean_text(h.get_text()).lower()
    if "unsere partner" in title or "unsere partner stellen sich vor" in title:
        unsere_blocks.append(combine_following_content(h))
    elif "weitere partner" in title:
        weitere_blocks.append(combine_following_content(h))

# Extract candidates
unsere_candidates = set()
weitere_candidates = set()

for blk in unsere_blocks:
    for a in blk.select("a[href]"):
        href = a.get("href") or ""
        u = urljoin(BASE_URL, href)
        parsed = urlparse(u)
        if "bde.de" in parsed.netloc.lower() and "/verband/mitgliedschaft/foerdermitglieder/" in parsed.path:
            unsere_candidates.add(u)

for blk in weitere_blocks:
    for a in blk.select("a[href]"):
        href = a.get("href") or ""
        u = urljoin(BASE_URL, href)
        parsed = urlparse(u)
        if parsed.scheme and parsed.netloc and "bde.de" not in parsed.netloc.lower():
            weitere_candidates.add(u)

# Fallbacks if nothing detected via headings
if not unsere_candidates:
    for a in soup.select('a[href*="/verband/mitgliedschaft/foerdermitglieder/"]'):
        u = urljoin(BASE_URL, a.get("href") or "")
        if u:
            unsere_candidates.add(u)

if not weitere_candidates:
    for a in soup.select("a[href]"):
        u = urljoin(BASE_URL, a.get("href") or "")
        p = urlparse(u)
        if p.scheme and p.netloc and "bde.de" not in p.netloc.lower():
            weitere_candidates.add(u)

# Build final list by visiting profile pages for unsere partner
rows = []
seen_websites = set()

for profile_url in sorted(unsere_candidates):
    name, website = find_external_website_on_profile(profile_url)
    if website and not urlparse(website).scheme:
        website = "https://" + website.lstrip("/")
    rows.append({
        "category": "unsere partner",
        "name": name,
        "website_url": website,
        "bde_profile_url": profile_url,
    })
    if website:
        seen_websites.add(website)
    time.sleep(0.2)

# Add weitere partner directly from page
for website in sorted(weitere_candidates):
    if is_social_url(website) or website in seen_websites:
        continue
    # Derive a readable name from domain as fallback
    domain = urlparse(website).netloc or website
    name_guess = re.sub(r"^www\.", "", domain)
    rows.append({
        "category": "weitere partner",
        "name": name_guess,
        "website_url": website,
        "bde_profile_url": None,
    })

# Create DataFrame
df = pd.DataFrame(rows) if rows else pd.DataFrame(columns=["category", "name", "website_url", "bde_profile_url"])  # ensure columns

# Sort and save
df["name"] = df["name"].fillna("").apply(clean_text).replace({"": None})
df = df.sort_values(by=["category", "name", "website_url"], na_position="last").reset_index(drop=True)

df.to_csv(OUTPUT_FILE, index=False)
print(f"Saved {len(df)} entries to {OUTPUT_FILE}")
print(df.groupby("category")["website_url"].count())

df.head(20)
# Out:
# Saved 55 entries to data/bde_foerdermitglieder.csv
# category
# unsere partner     28
# weitere partner    27
# Name: website_url, dtype: int64
#           category                                               name  \
# 0   unsere partner                 60 Jahre BDE – 60 Jahre Innovation
# 1   unsere partner                                               AMCS
# 2   unsere partner  APEX Container Lift Systeme GmbH – Innovation ...
# 3   unsere partner                                 Axians eWaste GmbH
# 4   unsere partner                                       Craemer GmbH
# 5   unsere partner                                          DAKO GmbH
# 6   unsere partner                       Doppstadt Umwelttechnik GmbH
# 7   unsere partner                              Dr. Ing. Wandrei GmbH
# 8   unsere partner                  Fagus-GreCon Greten GmbH & Co. KG
# 9   unsere partner                   Feistmantl Cleaning Systems GmbH
# 10  unsere partner                                   Fördermitglieder
# 11  unsere partner                     HKM Anhängerbau Altenburg GmbH
# 12  unsere partner                           Hübener Versicherungs AG
# 13  unsere partner                                           KBL GmbH
# 14  unsere partner                     Kooi Security Deutschland GmbH
# 15  unsere partner                          L∙Q∙M Marktforschung GmbH
# 16  unsere partner                          MOBA Mobile Automation AG
# 17  unsere partner                                         MOBOTIX AG
# 18  unsere partner                               PRESTO GmbH & Co. KG
# 19  unsere partner                                            PROLOGA
#
#                                           website_url  \
# 0                  https://www.avr-rechtsanwaelte.de/
# 1                       https://www.amcsgroup.com/de/
# 2                            https://www.apex-cls.de/
# 3                      https://www.axians-ewaste.com/
# 4                  https://www.craemer.com/startseite
# 5                        http://www.dako.de/entsorger
# 6                           https://www.doppstadt.de/
# 7                             https://www.wandrei.de/
# 8   https://www.fagus-grecon.com/de/brandschutz/br...
# 9                             https://feistmantl.com/
# 10                          https://www.amsberlin.de/
# 11                     http://www.hkm-fahrzeugbau.de/
# 12                            https://huebener-ag.eu/
# 13                            https://www.kblgmbh.de/
# 14                                https://247kooi.de/
# 15                 https://www.lqm-marktforschung.de/
# 16                         https://moba-automation.de
# 17                    mailto:emilia.birk@mobotix.com​
# 18                          https://www.presto.eu/de/
# 19                         https://prologa-group.com/
#
#                                       bde_profile_url
# 0   https://www.bde.de/verband/mitgliedschaft/foer...
# 1   https://www.bde.de/verband/mitgliedschaft/foer...
# 2   https://www.bde.de/verband/mitgliedschaft/foer...
# 3   https://www.bde.de/verband/mitgliedschaft/foer...
# 4   https://www.bde.de/verband/mitgliedschaft/foer...
# 5   https://www.bde.de/verband/mitgliedschaft/foer...
# 6   https://www.bde.de/verband/mitgliedschaft/foer...
# 7   https://www.bde.de/verband/mitgliedschaft/foer...
# 8   https://www.bde.de/verband/mitgliedschaft/foer...
# 9   https://www.bde.de/verband/mitgliedschaft/foer...
# 10  https://www.bde.de/verband/mitgliedschaft/foer...
# 11  https://www.bde.de/verband/mitgliedschaft/foer...
# 12  https://www.bde.de/verband/mitgliedschaft/foer...
# 13  https://www.bde.de/verband/mitgliedschaft/foer...
# 14  https://www.bde.de/verband/mitgliedschaft/foer...
# 15  https://www.bde.de/verband/mitgliedschaft/foer...
# 16  https://www.bde.de/verband/mitgliedschaft/foer...
# 17  https://www.bde.de/verband/mitgliedschaft/foer...
# 18  https://www.bde.de/verband/mitgliedschaft/foer...
# 19  https://www.bde.de/verband/mitgliedschaft/foer...

# %%
df.tail(20)
# Out:
#            category                           name  \
# 35  weitere partner                       fn.legal
# 36  weitere partner             gefahrgutjaeger.de
# 37  weitere partner                        gipa.de
# 38  weitere partner             loewe-container.de
# 39  weitere partner                    meiller.com
# 40  weitere partner              mueller-umwelt.de
# 41  weitere partner                        oklp.de
# 42  weitere partner                 orglmeister.de
# 43  weitere partner                  partslife.com
# 44  weitere partner  pauly-rechtsanwaelte-koeln.de
# 45  weitere partner            recyclingmagazin.de
# 46  weitere partner                      rewald.eu
# 47  weitere partner                 rosenbauer.com
# 48  weitere partner         satelliteindustries.de
# 49  weitere partner                      sensis.de
# 50  weitere partner                     sywatec.de
# 51  weitere partner                tegos-group.com
# 52  weitere partner                  terberg-hs.de
# 53  weitere partner                     umicore.de
# 54  weitere partner              zoeller-kipper.de
#
#                                           website_url bde_profile_url
# 35                               https://fn.legal/de/            None
# 36            http://www.gefahrgutjaeger.de/index.htm            None
# 37                               https://www.gipa.de/            None
# 38                    https://www.loewe-container.de/            None
# 39                        https://www.meiller.com/de/            None
# 40                     https://www.mueller-umwelt.de/            None
# 41                                   https://oklp.de/            None
# 42                        https://www.orglmeister.de/            None
# 43                         https://www.partslife.com/            None
# 44         https://www.pauly-rechtsanwaelte-koeln.de/            None
# 45                   https://www.recyclingmagazin.de/            None
# 46                             https://www.rewald.eu/            None
# 47  https://www.rosenbauer.com/de/at/world/produkt...            None
# 48                https://www.satelliteindustries.de/            None
# 49                                 https://sensis.de/            None
# 50                            https://www.sywatec.de/            None
# 51                    https://www.tegos-group.com/de/            None
# 52                         https://www.terberg-hs.de/            None
# 53                            https://www.umicore.de/            None
# 54                     https://www.zoeller-kipper.de/            None

# %% [markdown]
# # Netzwerk-Seite scrapen (Kooperationen und Initiativen, Mitgliedschaften, Unsere Partner)
#
# Diese Zelle extrahiert alle Einträge der Seite https://bde.de/verband/netzwerk/ aus den drei Slider-Sektionen:
# - Kooperationen und Initiativen
# - Mitgliedschaften
# - Unsere Partner
#
# Hinweis: Pro Karte gibt es i. d. R. einen externen Link zur jeweiligen Organisation. Diese werden hier direkt erfasst (internes BDE-Navigationsmaterial wird ignoriert).

# %%
import re
import time
import pathlib
from urllib.parse import urljoin, urlparse

import requests
from bs4 import BeautifulSoup
import pandas as pd

NETZWERK_URL = "https://bde.de/verband/netzwerk/"
OUT_DIR = pathlib.Path("data")
OUT_DIR.mkdir(parents=True, exist_ok=True)
OUT_FILE_NETZWERK = OUT_DIR / "bde_netzwerk.csv"

headers = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0 Safari/537.36",
}

sess = requests.Session()
sess.headers.update(headers)

r = sess.get(NETZWERK_URL, timeout=30)
r.raise_for_status()
s = BeautifulSoup(r.text, "lxml")


def clean(s: str | None) -> str:
    if not s:
        return ""
    return re.sub(r"\s+", " ", s).strip()


SOCIAL = {"linkedin.com", "facebook.com", "twitter.com", "x.com", "youtube.com", "instagram.com", "xing.com"}

section_keys = [
    "kooperationen und initiativen",
    "mitgliedschaften",
    "unsere partner",
]


def is_external(u: str) -> bool:
    p = urlparse(u)
    return bool(p.scheme and p.netloc) and "bde.de" not in p.netloc.lower()


def is_social(u: str) -> bool:
    host = urlparse(u).netloc.lower()
    return any(h in host for h in SOCIAL)


def nearest_section_key(node) -> str | None:
    # Walk backwards in document order to find the nearest H2/H3 heading
    for prev in node.previous_elements:
        name = getattr(prev, "name", None)
        if name in ("h2", "h3"):
            t = clean(prev.get_text()).lower()
            for key in section_keys:
                if key in t:
                    return key
    return None


rows = []
seen = set()

for a in s.select("a[href]"):
    href = a.get("href")
    if not href:
        continue
    url = urljoin(NETZWERK_URL, href)
    if not is_external(url) or is_social(url):
        continue
    key = nearest_section_key(a)
    if key not in section_keys:
        continue
    if url in seen:
        continue
    seen.add(url)
    name = clean(a.get_text())
    if not name:
        img = a.find("img")
        if img and img.get("alt"):
            name = clean(img.get("alt"))
    if not name:
        # fallback from domain
        domain = urlparse(url).netloc or url
        name = re.sub(r"^www\.", "", domain)
    rows.append({
        "section": key,
        "name": name or None,
        "url": url,
    })

net_df = pd.DataFrame(rows)
if net_df.empty:
    net_df = pd.DataFrame(columns=["section", "name", "url"])  # ensure columns
else:
    net_df = net_df.sort_values(["section", "name", "url"], na_position="last").reset_index(drop=True)

net_df.to_csv(OUT_FILE_NETZWERK, index=False)
print(f"Saved {len(net_df)} entries to {OUT_FILE_NETZWERK}")
print(net_df["section"].value_counts(dropna=False))
net_df.head(20)
# Out:
# Saved 61 entries to data/bde_netzwerk.csv
# section
# unsere partner                   47
# kooperationen und initiativen    10
# mitgliedschaften                  4
# Name: count, dtype: int64
#                           section  \
# 0   kooperationen und initiativen
# 1   kooperationen und initiativen
# 2   kooperationen und initiativen
# 3   kooperationen und initiativen
# 4   kooperationen und initiativen
# 5   kooperationen und initiativen
# 6   kooperationen und initiativen
# 7   kooperationen und initiativen
# 8   kooperationen und initiativen
# 9   kooperationen und initiativen
# 10               mitgliedschaften
# 11               mitgliedschaften
# 12               mitgliedschaften
# 13               mitgliedschaften
# 14                 unsere partner
# 15                 unsere partner
# 16                 unsere partner
# 17                 unsere partner
# 18                 unsere partner
# 19                 unsere partner
#
#                                                  name  \
# 0                         Aktion Biotonne Deutschland
# 1   BAV – Bundesverband der Altholzaufbereiter und...
# 2                           Bundesverband Altöl e. V.
# 3   Bundesvereinigung Recycling-Baustoffe e. V. (BRB)
# 4                            Germany Trade and Invest
# 5      Gesamtverband Schadstoffsanierung (GVSS) e. V.
# 6                    Initiative "Mülltrennung wirkt!"
# 7   Interessengemeinschaft der Aufbereiter und Ver...
# 8                              PREVENT Abfall-Allianz
# 9   ZER-QMS Zertifizierungsstelle, Qualitäts- und ...
# 10  BDI - Bundesverband der Deutschen Industrie e. V.
# 11     BNW Bundesverband Nachhaltige Wirtschaft e. V.
# 12  Europäische Föderation der Entsorgungswirtscha...
# 13  Landesvereinigung der Unternehmensverbände Nor...
# 14                                            AMCS BV
# 15                                          ASUP GmbH
# 16                                         Aurubis AG
# 17                                 Axians eWaste GmbH
# 18             BRANDI Rechtsanwälte Partnerschaft mbB
# 19                                       Craemer GmbH
#
#                                          url
# 0    https://aktion-biotonne-deutschland.de/
# 1                  https://altholzverband.de
# 2            https://bva-altoelrecycling.de/
# 3             https://recyclingbaustoffe.de/
# 4                https://www.gtai.de/gtai-de
# 5   https://www.gesamtverband-schadstoff.de/
# 6        https://www.muelltrennung-wirkt.de/
# 7                      https://igam-hmva.de/
# 8                 https://prevent-waste.net/
# 9                    https://www.zer-qms.de/
# 10                           https://bdi.eu/
# 11          https://www.bnw-bundesverband.de
# 12                      https://www.fead.be/
# 13              https://www.unternehmer.nrw/
# 14                 https://www.amcsgroup.de/
# 15                        https://asup.info/
# 16                https://www.aurubis.com/de
# 17            https://www.axians-ewaste.com/
# 18                   https://www.brandi.net/
# 19        https://www.craemer.com/startseite

# %%
# Vorschau Netzwerk mit klickbaren Links
import pandas as pd
from IPython.display import HTML

net_df = pd.read_csv("data/bde_netzwerk.csv")

def make_anchor(name, url):
    if not isinstance(url, str) or not url:
        return ""
    label = name.strip() if isinstance(name, str) and name.strip() else url
    return f'<a href="{url}" target="_blank" rel="noopener noreferrer">{label}</a>'

net_df["link"] = [make_anchor(n, u) for n, u in zip(net_df.get("name"), net_df.get("url"))]
HTML(net_df[["section", "name", "url", "link"]].to_html(escape=False, index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>section</th>
#       <th>name</th>
#       <th>url</th>
#       <th>link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>kooperationen und initiativen</td>
#       <td>Aktion Biotonne Deutschland</td>
#       <td>https://aktion-biotonne-deutschland.de/</td>
#       <td><a href="https://aktion-biotonne-deutschland.de/" target="_blank" rel="noopener noreferrer">Aktion Biotonne Deutschland</a></td>
#     </tr>
#     <tr>
#       <td>kooperationen und initiativen</td>
#       <td>BAV – Bundesverband der Altholzaufbereiter und -verwerter e. V.</td>
#       <td>https://altholzverband.de</td>
#       <td><a href="https://altholzverband.de" target="_blank" rel="noopener noreferrer">BAV – Bundesverband der Altholzaufbereiter und -verwerter e. V.</a></td>
#     </tr>
#     <tr>
#       <td>kooperationen und initiativen</td>
#       <td>Bundesverband Altöl e. V.</td>
#       <td>https://bva-altoelrecycling.de/</td>
#       <td><a href="https://bva-altoelrecycling.de/" target="_blank" rel="noopener noreferrer">Bundesverband Altöl e. V.</a></td>
#     </tr>
#     <tr>
#       <td>kooperationen und initiativen</td>
#       <td>Bundesvereinigung Recycling-Baustoffe e. V. (BRB)</td>
#       <td>https://recyclingbaustoffe.de/</td>
#       <td><a href="https://recyclingbaustoffe.de/" target="_blank" rel="noopener noreferrer">Bundesvereinigung Recycling-Baustoffe e. V. (BRB)</a></td>
#     </tr>
#     <tr>
#       <td>kooperationen und initiativen</td>
#       <td>Germany Trade and Invest</td>
#       <td>https://www.gtai.de/gtai-de</td>
#       <td><a href="https://www.gtai.de/gtai-de" target="_blank" rel="noopener noreferrer">Germany Trade and Invest</a></td>
#     </tr>
#     <tr>
#       <td>kooperationen und initiativen</td>
#       <td>Gesamtverband Schadstoffsanierung (GVSS) e. V.</td>
#       <td>https://www.gesamtverband-schadstoff.de/</td>
#       <td><a href="https://www.gesamtverband-schadstoff.de/" target="_blank" rel="noopener noreferrer">Gesamtverband Schadstoffsanierung (GVSS) e. V.</a></td>
#     </tr>
#     <tr>
#       <td>kooperationen und initiativen</td>
#       <td>Initiative "Mülltrennung wirkt!"</td>
#       <td>https://www.muelltrennung-wirkt.de/</td>
#       <td><a href="https://www.muelltrennung-wirkt.de/" target="_blank" rel="noopener noreferrer">Initiative "Mülltrennung wirkt!"</a></td>
#     </tr>
#     <tr>
#       <td>kooperationen und initiativen</td>
#       <td>Interessengemeinschaft der Aufbereiter und Verwerter von Müllverbrennungsschlacken (IGAM)</td>
#       <td>https://igam-hmva.de/</td>
#       <td><a href="https://igam-hmva.de/" target="_blank" rel="noopener noreferrer">Interessengemeinschaft der Aufbereiter und Verwerter von Müllverbrennungsschlacken (IGAM)</a></td>
#     </tr>
#     <tr>
#       <td>kooperationen und initiativen</td>
#       <td>PREVENT Abfall-Allianz</td>
#       <td>https://prevent-waste.net/</td>
#       <td><a href="https://prevent-waste.net/" target="_blank" rel="noopener noreferrer">PREVENT Abfall-Allianz</a></td>
#     </tr>
#     <tr>
#       <td>kooperationen und initiativen</td>
#       <td>ZER-QMS Zertifizierungsstelle, Qualitäts- und Umweltgutachter GmbH</td>
#       <td>https://www.zer-qms.de/</td>
#       <td><a href="https://www.zer-qms.de/" target="_blank" rel="noopener noreferrer">ZER-QMS Zertifizierungsstelle, Qualitäts- und Umweltgutachter GmbH</a></td>
#     </tr>
#     <tr>
#       <td>mitgliedschaften</td>
#       <td>BDI - Bundesverband der Deutschen Industrie e. V.</td>
#       <td>https://bdi.eu/</td>
#       <td><a href="https://bdi.eu/" target="_blank" rel="noopener noreferrer">BDI - Bundesverband der Deutschen Industrie e. V.</a></td>
#     </tr>
#     <tr>
#       <td>mitgliedschaften</td>
#       <td>BNW Bundesverband Nachhaltige Wirtschaft e. V.</td>
#       <td>https://www.bnw-bundesverband.de</td>
#       <td><a href="https://www.bnw-bundesverband.de" target="_blank" rel="noopener noreferrer">BNW Bundesverband Nachhaltige Wirtschaft e. V.</a></td>
#     </tr>
#     <tr>
#       <td>mitgliedschaften</td>
#       <td>Europäische Föderation der Entsorgungswirtschaft (FEAD)</td>
#       <td>https://www.fead.be/</td>
#       <td><a href="https://www.fead.be/" target="_blank" rel="noopener noreferrer">Europäische Föderation der Entsorgungswirtschaft (FEAD)</a></td>
#     </tr>
#     <tr>
#       <td>mitgliedschaften</td>
#       <td>Landesvereinigung der Unternehmensverbände Nordrhein-Westfalen e. V. (unternehmer nrw)</td>
#       <td>https://www.unternehmer.nrw/</td>
#       <td><a href="https://www.unternehmer.nrw/" target="_blank" rel="noopener noreferrer">Landesvereinigung der Unternehmensverbände Nordrhein-Westfalen e. V. (unternehmer nrw)</a></td>
#     </tr>
#     <tr>
#       <td>unsere partner</td>
#       <td>AMCS BV</td>
#       <td>https://www.amcsgroup.de/</td>
#       <td><a href="https://www.amcsgroup.de/" target="_blank" rel="noopener noreferrer">AMCS BV</a></td>
#     </tr>
#     <tr>
#       <td>unsere partner</td>
#       <td>ASUP GmbH</td>
#       <td>https://asup.info/</td>
#       <td><a href="https://asup.info/" target="_blank" rel="noopener noreferrer">ASUP GmbH</a></td>
#     </tr>
#     <tr>
#       <td>unsere partner</td>
#       <td>Aurubis AG</td>
#       <td>https://www.aurubis.com/de</td>
#       <td><a href="https://www.aurubis.com/de" target="_blank" rel="noopener noreferrer">Aurubis AG</a></td>
#     </tr>
#     <tr>
#       <td>unsere partner</td>
#       <td>Axians eWaste GmbH</td>
#       <td>https://www.axians-ewaste.com/</td>
#       <td><a href="https://www.axians-ewaste.com/" target="_blank" rel="noopener noreferrer">Axians eWaste GmbH</a></td>
#     </tr>
#     <tr>
#       <td>unsere partner</td>
#       <td>BRANDI Rechtsanwälte Partnerschaft mbB</td>
#       <td>https://www.brandi.net/</td>
#       <td><a href="https://www.brandi.net/" target="_blank" rel="noopener noreferrer">BRANDI Rechtsanwälte Partnerschaft mbB</a></td>
#     </tr>
#     <tr>
#       <td>unsere partner</td>
#       <td>Craemer GmbH</td>
#       <td>https://www.craemer.com/startseite</td>
#       <td><a href="https://www.craemer.com/startseite" target="_blank" rel="noopener noreferrer">Craemer GmbH</a></td>
#     </tr>
#     <tr>
#       <td>unsere partner</td>
#       <td>DETAIL Business Information GmbH</td>
#       <td>http://www.recyclingmagazin.de/</td>
#       <td><a href="http://www.recyclingmagazin.de/" target="_blank" rel="noopener noreferrer">DETAIL Business Information GmbH</a></td>
#     </tr>
#     <tr>
#       <td>unsere partner</td>
#       <td>Daimler Truck AG</td>
#       <td>https://www.daimler-truck.com/de/</td>
#       <td><a href="https://www.daimler-truck.com/de/" target="_blank" rel="noopener noreferrer">Daimler Truck AG</a></td>
#     </tr>
#     <tr>
#       <td>unsere partner</td>
#       <td>Doppstadt Umwelttechnik GmbH</td>
#       <td>https://www.doppstadt.de/</td>
#       <td><a href="https://www.doppstadt.de/" target="_blank" rel="noopener noreferrer">Doppstadt Umwelttechnik GmbH</a></td>
#     </tr>
#     <tr>
#       <td>unsere partner</td>
#       <td>Dr. Ing. Wandrei GmbH</td>
#       <td>http://www.wandrei.de/</td>
#       <td><a href="http://www.wandrei.de/" target="_blank" rel="noopener noreferrer">Dr. Ing. Wandrei GmbH</a></td>
#     </tr>
#     <tr>
#       <td>unsere partner</td>
#       <td>ESE GmbH</td>
#       <td>http://www.ese.com/</td>
#       <td><a href="http://www.ese.com/" target="_blank" rel="noopener noreferrer">ESE GmbH</a></td>
#     </tr>
#     <tr>
#       <td>unsere partner</td>
#       <td>F. X. MEILLER Fahrzeug- und Maschinenfabrik - GmbH & Co. KG</td>
#       <td>http://www.meiller.com/</td>
#       <td><a href="http://www.meiller.com/" target="_blank" rel="noopener noreferrer">F. X. MEILLER Fahrzeug- und Maschinenfabrik - GmbH & Co. KG</a></td>
#     </tr>
#     <tr>
#       <td>unsere partner</td>
#       <td>FAUN Umwelttechnik GmbH & Co. KG</td>
#       <td>http://www.faun.com/</td>
#       <td><a href="http://www.faun.com/" target="_blank" rel="noopener noreferrer">FAUN Umwelttechnik GmbH & Co. KG</a></td>
#     </tr>
#     <tr>
#       <td>unsere partner</td>
#       <td>Feistmantl Cleaning Systems GmbH</td>
#       <td>http://www.

# %%
# Kombiniere alle Daten in ein gemeinsames CSV
import pandas as pd
from pathlib import Path

out_dir = Path("data")
combined_path = out_dir / "bde_scrape.csv"

# Load Fördermitglieder (if exists)
df_foerd = None
p1 = out_dir / "bde_foerdermitglieder.csv"
if p1.exists():
    df_foerd = pd.read_csv(p1)
    # Normalize column names
    df_foerd = df_foerd.rename(columns={
        "category": "section",
        "website_url": "url",
        "bde_profile_url": "profile_url",
    })
    if "section" not in df_foerd.columns:
        df_foerd["section"] = "foerdermitglieder"
    df_foerd["source_page"] = "foerdermitglieder"

# Load Netzwerk (if exists)
df_netz = None
p2 = out_dir / "bde_netzwerk.csv"
if p2.exists():
    df_netz = pd.read_csv(p2)
    df_netz["profile_url"] = None
    df_netz["source_page"] = "netzwerk"

# Concatenate
frames = [d for d in [df_foerd, df_netz] if d is not None]
if frames:
    df_all = pd.concat(frames, ignore_index=True, sort=False)
else:
    df_all = pd.DataFrame(columns=["section", "name", "url", "profile_url", "source_page"])  # empty

# Standardize columns and order
for c in ["section", "name", "url", "profile_url", "source_page"]:
    if c not in df_all.columns:
        df_all[c] = None

# Deduplicate by URL + name to be safe
df_all = df_all.drop_duplicates(subset=["name", "url"]).sort_values(
    by=["source_page", "section", "name", "url"], na_position="last"
).reset_index(drop=True)

# Save
df_all.to_csv(combined_path, index=False)
print(f"Saved {len(df_all)} combined rows to {combined_path}")
try:
    print(df_all.groupby(["source_page", "section"]).size())
except Exception:
    pass

df_all.head(20)
# Out:
# Saved 108 combined rows to data/bde_scrape.csv
# source_page        section
# foerdermitglieder  unsere partner                   28
#                    weitere partner                  27
# netzwerk           kooperationen und initiativen    10
#                    mitgliedschaften                  4
#                    unsere partner                   39
# dtype: int64
#            section                                               name  \
# 0   unsere partner                 60 Jahre BDE – 60 Jahre Innovation
# 1   unsere partner                                               AMCS
# 2   unsere partner  APEX Container Lift Systeme GmbH – Innovation ...
# 3   unsere partner                                 Axians eWaste GmbH
# 4   unsere partner                                       Craemer GmbH
# 5   unsere partner                                          DAKO GmbH
# 6   unsere partner                       Doppstadt Umwelttechnik GmbH
# 7   unsere partner                              Dr. Ing. Wandrei GmbH
# 8   unsere partner                  Fagus-GreCon Greten GmbH & Co. KG
# 9   unsere partner                   Feistmantl Cleaning Systems GmbH
# 10  unsere partner                                   Fördermitglieder
# 11  unsere partner                     HKM Anhängerbau Altenburg GmbH
# 12  unsere partner                           Hübener Versicherungs AG
# 13  unsere partner                                           KBL GmbH
# 14  unsere partner                     Kooi Security Deutschland GmbH
# 15  unsere partner                          L∙Q∙M Marktforschung GmbH
# 16  unsere partner                          MOBA Mobile Automation AG
# 17  unsere partner                                         MOBOTIX AG
# 18  unsere partner                               PRESTO GmbH & Co. KG
# 19  unsere partner                                            PROLOGA
#
#                                                   url  \
# 0                  https://www.avr-rechtsanwaelte.de/
# 1                       https://www.amcsgroup.com/de/
# 2                            https://www.apex-cls.de/
# 3                      https://www.axians-ewaste.com/
# 4                  https://www.craemer.com/startseite
# 5                        http://www.dako.de/entsorger
# 6                           https://www.doppstadt.de/
# 7                             https://www.wandrei.de/
# 8   https://www.fagus-grecon.com/de/brandschutz/br...
# 9                             https://feistmantl.com/
# 10                          https://www.amsberlin.de/
# 11                     http://www.hkm-fahrzeugbau.de/
# 12                            https://huebener-ag.eu/
# 13                            https://www.kblgmbh.de/
# 14                                https://247kooi.de/
# 15                 https://www.lqm-marktforschung.de/
# 16                         https://moba-automation.de
# 17                    mailto:emilia.birk@mobotix.com​
# 18                          https://www.presto.eu/de/
# 19                         https://prologa-group.com/
#
#                                           profile_url        source_page
# 0   https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 1   https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 2   https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 3   https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 4   https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 5   https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 6   https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 7   https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 8   https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 9   https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 10  https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 11  https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 12  https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 13  https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 14  https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 15  https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 16  https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 17  https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 18  https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 19  https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder

# %%
df_all.sample(10)
# Out:
#               section                                               name  \
# 26     unsere partner                 ZER-QMS Zertifizierungsstelle GmbH
# 100    unsere partner                                    Terberg HS GmbH
# 48    weitere partner                             satelliteindustries.de
# 34    weitere partner                                           faun.com
# 79     unsere partner                   Feistmantl Cleaning Systems GmbH
# 91     unsere partner                               PRESTO GmbH & Co. KG
# 19     unsere partner                                            PROLOGA
# 97     unsere partner                          Satellite Industries GmbH
# 96     unsere partner                              SULO Deutschland GmbH
# 68   mitgliedschaften  Landesvereinigung der Unternehmensverbände Nor...
#
#                                      url  \
# 26                https://www.zer-qms.de
# 100           https://www.terberg-hs.de/
# 48   https://www.satelliteindustries.de/
# 34                 https://www.faun.com/
# 79            http://www.feistmantl.com/
# 91               http://www.presto.eu/de
# 19            https://prologa-group.com/
# 97    http://www.satelliteindustries.de/
# 96                      https://sulo.de/
# 68          https://www.unternehmer.nrw/
#
#                                            profile_url        source_page
# 26   https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 100                                               None           netzwerk
# 48                                                 NaN  foerdermitglieder
# 34                                                 NaN  foerdermitglieder
# 79                                                None           netzwerk
# 91                                                None           netzwerk
# 19   https://www.bde.de/verband/mitgliedschaft/foer...  foerdermitglieder
# 97                                                None           netzwerk
# 96                                                None           netzwerk
# 68                                                None           netzwerk
