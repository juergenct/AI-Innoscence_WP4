# %%
import pandas as pd

# %%
df_company = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/PitchBook Dump TUHH/Company.csv')

# %%
df_company.columns
# Out:
# Index(['CompanyID', 'CompanyName', 'CompanyAlsoKnownAs', 'CompanyFormerName',
#        'CompanyLegalName', 'Description', 'Keywords', 'CompanyFinancingStatus',
#        'TotalRaised', 'BusinessStatus', 'OwnershipStatus', 'Universe',
#        'Website', 'Employees', 'Exchange', 'Ticker', 'YearFounded',
#        'ParentCompany', 'ParentCompanyID', 'HQLocation', 'HQAddressLine1',
#        'HQAddressLine2', 'HQCity', 'HQState_Province', 'HQPostCode',
#        'HQCountry', 'HQPhone', 'HQFax', 'HQEmail', 'HQGlobalRegion',
#        'HQGlobalSubRegion', 'LastUpdated'],
#       dtype='object')

# %%
# Filter df_company for entries where HQCountry is 'Serbia'
df_company_ger = df_company[df_company['HQCountry'] == "Germany"]

# %%
df_company_ger['HQCity'] = df_company_ger['HQCity'].astype(str)
df_company_ger['HQState_Province'] = df_company_ger['HQState_Province'].astype(str)
# Out:
# /tmp/ipykernel_3921448/4214577234.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_company_ger['HQCity'] = df_company_ger['HQCity'].astype(str)
# /tmp/ipykernel_3921448/4214577234.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_company_ger['HQState_Province'] = df_company_ger['HQState_Province'].astype(str)

# %%
# Filter df_company_ger for entries where HQCity or HQState_Province is 'Hamburg'
df_company_ger = df_company_ger[(df_company_ger['HQCity'] == "Hamburg") | (df_company_ger['HQState_Province'] == "Hamburg")]
len(df_company_ger)
# Out:
# 629

# %%
df_company_ger.to_csv('/home/thiesen/Documents/AI-Innoscence_Ecosystem/Input/Hamburg/Input Data Files/pitchbook_companies_Germany.csv', index=False)
