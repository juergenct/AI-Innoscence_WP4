# %%
import pandas as pd

# %% [markdown]
# # Add the following entities by hand and save to CSV
# Bundesverband Kreislaufwirtschaft (BDE) - https://www.bde.de/
# CEWI - Circular Economy Initiative Deutschland - https://www.circular-economy-initiative.de/
# PREVENT Abfall Allianz - https://prevent-waste.net/
# German RETech Partnership - https://www.retech-germany.net/
# EEHH Cluster (Erneuerbare Energien Hamburg) - https://eehh.de/
# Hamburg Invest Portfolios - https://www.hamburg-invest.com/
# Umweltpartnerschaft Hamburg - https://www.umweltpartnerschaft.hamburg.de/

# %%
df = pd.DataFrame({
    'Name': [
        'Bundesverband Kreislaufwirtschaft (BDE)',
        'CEWI - Circular Economy Initiative Deutschland',
        'PREVENT Abfall Allianz',
        'German RETech Partnership',
        'EEHH Cluster (Erneuerbare Energien Hamburg)',
        'Hamburg Invest Portfolios',
        'Umweltpartnerschaft Hamburg'
    ],
    'URL': [
        'https://www.bde.de/',
        'https://www.circular-economy-initiative.de/',
        'https://prevent-waste.net/',
        'https://www.retech-germany.net/',
        'https://eehh.de/',
        'https://www.hamburg-invest.com/',
        'https://www.umweltpartnerschaft.hamburg.de/'
    ]
})
df.to_csv('additional_ce_entities.csv', index=False)
