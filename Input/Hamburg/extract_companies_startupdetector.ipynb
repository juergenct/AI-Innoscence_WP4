# %%
import pandas as pd

# %%
df_companies_2014 = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/Startup Detector/2024-10/tuhh-companies/tuhh_companies_2014.csv')
# Keep only companies where either City or Bundesland is 'Hamburg'
df_companies_2014 = df_companies_2014[(df_companies_2014['City'] == 'Hamburg') | (df_companies_2014['Bundesland'] == 'Hamburg')]

df_companies_2015 = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/Startup Detector/2024-10/tuhh-companies/tuhh_companies_2015.csv')
# Keep only companies where either City or Bundesland is 'Hamburg'
df_companies_2015 = df_companies_2015[(df_companies_2015['City'] == 'Hamburg') | (df_companies_2015['Bundesland'] == 'Hamburg')]

df_companies_2016 = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/Startup Detector/2024-10/tuhh-companies/tuhh_companies_2016.csv')
# Keep only companies where either City or Bundesland is 'Hamburg'
df_companies_2016 = df_companies_2016[(df_companies_2016['City'] == 'Hamburg') | (df_companies_2016['Bundesland'] == 'Hamburg')] 

df_companies_2017 = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/Startup Detector/2024-10/tuhh-companies/tuhh_companies_2017.csv')
# Keep only companies where either City or Bundesland is 'Hamburg'
df_companies_2017 = df_companies_2017[(df_companies_2017['City'] == 'Hamburg') | (df_companies_2017['Bundesland'] == 'Hamburg')]

df_companies_2018 = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/Startup Detector/2024-10/tuhh-companies/tuhh_companies_2018.csv')
# Keep only companies where either City or Bundesland is 'Hamburg'
df_companies_2018 = df_companies_2018[(df_companies_2018['City'] == 'Hamburg') | (df_companies_2018['Bundesland'] == 'Hamburg')]

df_companies_2019 = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/Startup Detector/2024-10/tuhh-companies/tuhh_companies_2019.csv')
# Keep only companies where either City or Bundesland is 'Hamburg'
df_companies_2019 = df_companies_2019[(df_companies_2019['City'] == 'Hamburg') | (df_companies_2019['Bundesland'] == 'Hamburg')]

df_companies_2020 = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/Startup Detector/2024-10/tuhh-companies/tuhh_companies_2020.csv')
# Keep only companies where either City or Bundesland is 'Hamburg'
df_companies_2020 = df_companies_2020[(df_companies_2020['City'] == 'Hamburg') | (df_companies_2020['Bundesland'] == 'Hamburg')]

df_companies_2021 = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/Startup Detector/2024-10/tuhh-companies/tuhh_companies_2021.csv')
# Keep only companies where either City or Bundesland is 'Hamburg'
df_companies_2021 = df_companies_2021[(df_companies_2021['City'] == 'Hamburg') | (df_companies_2021['Bundesland'] == 'Hamburg')]

df_companies_2022 = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/Startup Detector/2024-10/tuhh-companies/tuhh_companies_2022.csv')
# Keep only companies where either City or Bundesland is 'Hamburg'
df_companies_2022 = df_companies_2022[(df_companies_2022['City'] == 'Hamburg') | (df_companies_2022['Bundesland'] == 'Hamburg')]

df_companies_2023 = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/Startup Detector/2024-10/tuhh-companies/tuhh_companies_2023.csv')
# Keep only companies where either City or Bundesland is 'Hamburg'
df_companies_2023 = df_companies_2023[(df_companies_2023['City'] == 'Hamburg') | (df_companies_2023['Bundesland'] == 'Hamburg')]

# %%
df_companies = pd.concat([df_companies_2014, df_companies_2015, df_companies_2016, df_companies_2017, df_companies_2018, df_companies_2019, df_companies_2020, df_companies_2021, df_companies_2022, df_companies_2023])
df_companies = df_companies.drop_duplicates(subset=['ID'], keep='last')
df_companies = df_companies.reset_index(drop=True)

# %%
df_companies.to_csv('/home/thiesen/Documents/AI-Innoscence_Ecosystem/Input/Hamburg/Input Data Files/startupdetector_companies_Hamburg.csv', index=False)
