# %%
import pandas as pd

# %%
df_organizations = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/CrunchBase Dump TUHH/organizations.csv')

# %%
df_organizations.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'legal_name', 'roles', 'domain', 'homepage_url',
#        'country_code', 'state_code', 'region', 'city', 'address',
#        'postal_code', 'status', 'short_description', 'category_list',
#        'category_groups_list', 'num_funding_rounds', 'total_funding_usd',
#        'total_funding', 'total_funding_currency_code', 'founded_on',
#        'last_funding_on', 'closed_on', 'employee_count', 'email', 'phone',
#        'facebook_url', 'linkedin_url', 'twitter_url', 'logo_url', 'alias1',
#        'alias2', 'alias3', 'primary_role', 'num_exits'],
#       dtype='object')

# %%
# Filter df_organizations for entries where 'country_code' is 'DEU'
df_organizations = df_organizations[df_organizations['country_code'] == "DEU"]
# Filter df_organizations for entries where 'region' or 'city' is 'Hamburg'
df_organizations = df_organizations[df_organizations['city'] == "Hamburg"]

# %%
df_organizations.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'legal_name', 'roles', 'domain', 'homepage_url',
#        'country_code', 'state_code', 'region', 'city', 'address',
#        'postal_code', 'status', 'short_description', 'category_list',
#        'category_groups_list', 'num_funding_rounds', 'total_funding_usd',
#        'total_funding', 'total_funding_currency_code', 'founded_on',
#        'last_funding_on', 'closed_on', 'employee_count', 'email', 'phone',
#        'facebook_url', 'linkedin_url', 'twitter_url', 'logo_url', 'alias1',
#        'alias2', 'alias3', 'primary_role', 'num_exits'],
#       dtype='object')

# %%
df_organizations['homepage_url'].head()
# Out:
# 492              http://www.jimdo.com
# 1490    http://www.myneighborhood.net
# 1833      http://www.ammerpartners.vc
# 1892              http://www.xing.com
# 2008                http://www.bsi.ag
# Name: homepage_url, dtype: object

# %%
df_organizations['city'].value_counts()
# Out:
# city
# Hamburg    4769
# Name: count, dtype: int64

# %%
len(df_organizations)
# Out:
# 4769

# %%
df_organizations.to_csv('/home/thiesen/Documents/AI-Innoscence_Ecosystem/Input/Hamburg/Input Data Filescrunchbase_companies_DEU_Hamburg.csv', index=False)

# %%
df_investors = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/CrunchBase Dump TUHH/investors.csv')

# %%
df_investors.columns
# Out:
# Index(['uuid', 'name', 'type', 'permalink', 'cb_url', 'rank', 'created_at',
#        'updated_at', 'roles', 'domain', 'country_code', 'state_code', 'region',
#        'city', 'investor_types', 'investment_count', 'total_funding_usd',
#        'total_funding', 'total_funding_currency_code', 'founded_on',
#        'closed_on', 'facebook_url', 'linkedin_url', 'twitter_url', 'logo_url'],
#       dtype='object')

# %%
# Filter df_investors for entries where 'country_code' is 'DEU'
df_investors = df_investors[df_investors['country_code'] == "DEU"]
# Filter df_investors for entries where 'region' or 'city' is 'Hamburg'
df_investors = df_investors[df_investors['city'] == "Hamburg"]

# %%
df_investors.to_csv('/home/thiesen/Documents/AI-Innoscence_Ecosystem/Input/Hamburg/Input Data Files/crunchbase_investors_DEU_Hamburg.csv', index=False)
