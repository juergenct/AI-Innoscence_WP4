# %% [markdown]
# # Moldovan research ecosystem scraper (.md/.ro)
#
# This notebook scrapes two ANCD pages and extracts organization names with website domains ending in .md (Moldova) or .ro (Romania):
#
# - Innovation incubators and science/technology parks: https://ancd.gov.md/en/content/innovation-incubators-science-and-technology-parks
# - Research organizations: https://ancd.gov.md/en/content/research-organizations
#
# What you get:
# - Two CSV files saved in the same directory as this notebook:
#   - innovation_incubators_parks_md_ro.csv
#   - research_organizations_md_ro.csv
#
# How to use:
# - Run the code cell below. It will fetch the pages, parse them, filter to .md/.ro domains, display the results, and save the CSVs.

# %%
# Simple scraper for two ANCD pages (filters to .md/.ro)
import re
from pathlib import Path
from urllib.parse import urlparse, urljoin

import pandas as pd
import requests
from bs4 import BeautifulSoup


# ---------- HTTP and parsing helpers ----------
def fetch_soup(url: str, timeout: int = 30) -> BeautifulSoup:
    headers = {
        "User-Agent": (
            "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
            "(KHTML, like Gecko) Chrome/120.0 Safari/537.36"
        )
    }
    resp = requests.get(url, headers=headers, timeout=timeout)
    resp.raise_for_status()
    return BeautifulSoup(resp.text, "lxml")


def canonicalize_url(base_url: str, href: str | None) -> str | None:
    if not href:
        return None
    href = href.strip()
    # Turn scheme-less urls like 'www.site.md' into http://www.site.md
    if href.startswith("www."):
        href = "http://" + href
    return urljoin(base_url, href)


def extract_domain(url: str | None) -> str:
    if not url:
        return ""
    p = urlparse(url)
    host = p.netloc or ""
    if not host and p.path.startswith("www."):
        host = p.path.split("/")[0]
    host = host.lower()
    if host.startswith("www."):
        host = host[4:]
    return host


def is_md_or_ro(host: str) -> bool:
    return host.endswith(".md") or host.endswith(".ro")


# ---------- Scrapers ----------
def scrape_innovation_incubators(url: str) -> pd.DataFrame:
    """Extract links and associated entity names from the page text.
    Heuristics:
    - For each anchor with .md/.ro, use the nearest <li> text (before 'Pagina web') as the entity name.
    - Fallback to surrounding paragraph or the link text itself.
    - Deduplicate by domain.
    """
    soup = fetch_soup(url)
    rows: list[dict] = []

    for a in soup.find_all("a", href=True):
        full_url = canonicalize_url(url, a.get("href"))
        domain = extract_domain(full_url)
        if not is_md_or_ro(domain):
            continue

        # Try to infer entity name from the nearest list item or paragraph
        name = None
        li = a.find_parent("li")
        if li is not None:
            text = " ".join(li.stripped_strings)
            parts = re.split(r"pagina\s*web\s*: ?", text, flags=re.IGNORECASE)
            candidate = parts[0].strip() if parts else text.strip()
            # Prefer quoted entity names if present
            m = re.search(r"[\"“„]([^\"””]+)[\"””]", candidate)
            name = (m.group(1).strip() if m else candidate)
        else:
            p = a.find_parent(["p", "div"]) or soup
            text = " ".join(p.stripped_strings)
            parts = re.split(r"pagina\s*web\s*: ?", text, flags=re.IGNORECASE)
            candidate = parts[0].strip() if parts else (a.get_text(strip=True) or domain)
            name = candidate or domain

        if not name:
            name = a.get_text(strip=True) or domain

        rows.append({
            "source": url,
            "entity_name": name,
            "url": full_url,
            "domain": domain,
        })

    df = pd.DataFrame(rows)
    if not df.empty:
        df = df.drop_duplicates(subset=["domain"]).reset_index(drop=True)
    return df


def scrape_research_organizations(url: str) -> pd.DataFrame:
    """Parse tables and extract organization name (2nd column) and website link (3rd+ columns).
    Only keep .md/.ro domains and deduplicate by domain.
    """
    soup = fetch_soup(url)
    rows: list[dict] = []

    for table in soup.find_all("table"):
        for tr in table.find_all("tr"):
            cells = tr.find_all(["td", "th"])
            if len(cells) < 3:
                continue
            name = cells[1].get_text(" ", strip=True)
            link_tag = None
            # The site is usually in the 3rd column; search 3rd+ just in case
            for td in cells[2:]:
                link_tag = td.find("a", href=True)
                if link_tag:
                    break
            if not link_tag:
                continue
            full_url = canonicalize_url(url, link_tag.get("href"))
            domain = extract_domain(full_url)
            if not is_md_or_ro(domain):
                continue
            # Clean leading numbering like "1." or "2)"
            name = re.sub(r"^\s*\d+[\.)]\s*", "", name)
            rows.append({
                "source": url,
                "entity_name": name,
                "url": full_url,
                "domain": domain,
            })

    df = pd.DataFrame(rows)
    if not df.empty:
        df = df.drop_duplicates(subset=["domain"]).reset_index(drop=True)
    return df


# ---------- Main run ----------
URL_INCUBATORS = "https://ancd.gov.md/en/content/innovation-incubators-science-and-technology-parks"
URL_RESEARCH = "https://ancd.gov.md/en/content/research-organizations"

incubators_df = scrape_innovation_incubators(URL_INCUBATORS)
research_df = scrape_research_organizations(URL_RESEARCH)

# Save results next to this notebook
out_dir = Path.cwd()
file_incubators = out_dir / "innovation_incubators_parks_md_ro.csv"
file_research = out_dir / "research_organizations_md_ro.csv"

incubators_df.to_csv(file_incubators, index=False)
research_df.to_csv(file_research, index=False)

print("Saved files:")
print(file_incubators)
print(file_research)

# Display a preview
display(incubators_df)
display(research_df)
# Out:
# /home/thiesen/.conda/envs/AI_Innoscence/lib/python3.11/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Saved files:
# /home/thiesen/Documents/AI-Innoscence_Ecosystem/Input/Cahul/innovation_incubators_parks_md_ro.csv
# /home/thiesen/Documents/AI-Innoscence_Ecosystem/Input/Cahul/research_organizations_md_ro.csv
#                                                source  \
# 0   https://ancd.gov.md/en/content/innovation-incu...
# 1   https://ancd.gov.md/en/content/innovation-incu...
# 2   https://ancd.gov.md/en/content/innovation-incu...
# 3   https://ancd.gov.md/en/content/innovation-incu...
# 4   https://ancd.gov.md/en/content/innovation-incu...
# 5   https://ancd.gov.md/en/content/innovation-incu...
# 6   https://ancd.gov.md/en/content/innovation-incu...
# 7   https://ancd.gov.md/en/content/innovation-incu...
# 8   https://ancd.gov.md/en/content/innovation-incu...
# 9   https://ancd.gov.md/en/content/innovation-incu...
# 10  https://ancd.gov.md/en/content/innovation-incu...
# 11  https://ancd.gov.md/en/content/innovation-incu...
# 12  https://ancd.gov.md/en/content/innovation-incu...
# 13  https://ancd.gov.md/en/content/innovation-incu...
# 14  https://ancd.gov.md/en/content/innovation-incu...
#
#                                    entity_name  \
# 0                         Skip to main content
# 1   Horizon Europe National Office Description
# 2                              pstacademica.md
# 3                             incubator.utm.md
# 4                               inno-center.md
# 5                             inventica.usm.md
# 6                                 it4ba.ase.md
# 7                                   edu.asm.md
# 8                               biodanubius.ro
# 9                                 Sesizați CNA
# 10                 Guvernul Republicii Moldova
# 11                         E-Governance Agency
# 12                Portalul serviciilor publice
# 13                   Portalul datelor deschide
# 14                     Portalul de participare
#
#                                                   url            domain
# 0   https://ancd.gov.md/en/content/innovation-incu...       ancd.gov.md
# 1                         https://horizoneurope.md/ro  horizoneurope.md
# 2                             http://pstacademica.md/   pstacademica.md
# 3                        http://www.incubator.utm.md/  incubator.utm.md
# 4                          http://www.inno-center.md/    inno-center.md
# 5                        http://www.inventica.usm.md/  inventica.usm.md
# 6                            http://www.it4ba.ase.md/      it4ba.ase.md
# 7   http://edu.asm.md/en/content/univer-science-cl...        edu.asm.md
# 8                          http://www.biodanubius.ro/    biodanubius.ro
# 9   https://www.cna.md/pageview.php?l=ro&idc=112&t...            cna.md
# 10                                  https://gov.md/ro            gov.md
# 11                   http://www.egov.md/index.php/en/           egov.md
# 12                           https://servicii.gov.md/   servicii.gov.md
# 13                                http://data.gov.md/       data.gov.md
# 14                            http://particip.gov.md/   particip.gov.md
#                                                source  \
# 0   https://ancd.gov.md/en/content/research-organi...
# 1   https://ancd.gov.md/en/content/research-organi...
# 2   https://ancd.gov.md/en/content/research-organi...
# 3   https://ancd.gov.md/en/content/research-organi...
# 4   https://ancd.gov.md/en/content/research-organi...
# 5   https://ancd.gov.md/en/content/research-organi...
# 6   https://ancd.gov.md/en/content/research-organi...
# 7   https://ancd.gov.md/en/content/research-organi...
# 8   https://ancd.gov.md/en/content/research-organi...
# 9   https://ancd.gov.md/en/content/research-organi...
# 10  https://ancd.gov.md/en/content/research-organi...
# 11  https://ancd.gov.md/en/content/research-organi...
# 12  https://ancd.gov.md/en/content/research-organi...
# 13  https://ancd.gov.md/en/content/research-organi...
# 14  https://ancd.gov.md/en/content/research-organi...
# 15  https://ancd.gov.md/en/content/research-organi...
# 16  https://ancd.gov.md/en/content/research-organi...
# 17  https://ancd.gov.md/en/content/research-organi...
# 18  https://ancd.gov.md/en/content/research-organi...
# 19  https://ancd.gov.md/en/content/research-organi...
# 20  https://ancd.gov.md/en/content/research-organi...
# 21  https://ancd.gov.md/en/content/research-organi...
# 22  https://ancd.gov.md/en/content/research-organi...
# 23  https://ancd.gov.md/en/content/research-organi...
# 24  https://ancd.gov.md/en/content/research-organi...
# 25  https://ancd.gov.md/en/content/research-organi...
# 26  https://ancd.gov.md/en/content/research-organi...
# 27  https://ancd.gov.md/en/content/research-organi...
# 28  https://ancd.gov.md/en/content/research-organi...
# 29  https://ancd.gov.md/en/content/research-organi...
# 30  https://ancd.gov.md/en/content/research-organi...
# 31  https://ancd.gov.md/en/content/research-organi...
# 32  https://ancd.gov.md/en/content/research-organi...
# 33  https://ancd.gov.md/en/content/research-organi...
# 34  https://ancd.gov.md/en/content/research-organi...
# 35  https://ancd.gov.md/en/content/research-organi...
# 36  https://ancd.gov.md/en/content/research-organi...
# 37  https://ancd.gov.md/en/content/research-organi...
# 38  https://ancd.gov.md/en/content/research-organi...
# 39  https://ancd.gov.md/en/content/research-organi...
# 40  https://ancd.gov.md/en/content/research-organi...
# 41  https://ancd.gov.md/en/content/research-organi...
# 42  https://ancd.gov.md/en/content/research-organi...
# 43  https://ancd.gov.md/en/content/research-organi...
# 44  https://ancd.gov.md/en/content/research-organi...
# 45  https://ancd.gov.md/en/content/research-organi...
#
#                                           entity_name  \
# 0                   Universitatea de Stat din Moldova
# 1   Universitatea Pedagogică de Stat din Moldova ”...
# 2   Universitatea Pedagogică de Stat ”Alecu Russo”...
# 3   Universitatea de Stat de Educație Fizică și Sport
# 4           Universitatea de Stat ”Dimitrie Cantemir”
# 5                Universitatea Cooperatist Comercială
# 6                    Universitatea Tehnică a Moldovei
# 7            Academia de Studii Economice din Moldova
# 8         Academia de Muzică, Teatru și Arte Plastice
# 9                 Institutul de Științe ale Educației
# 10                               Institutul de Chimie
# 11  Institutul de Matematică și Informatică ”Vladi...
# 12                      Institutul de Fizică Aplicată
# 13              Institutul de Geologie și Seismologie
# 14                             Institutul de Zoologie
# 15                Institutul de Ecologie și Geografie
# 16  Institutul de Inginerie Electronică și Nanoteh...
# 17                           Institutul de Energetică
# 18        Institutul de Fiziologie și Sanocreatologie
# 19       Institutul de Microbiologie și Biotehnologie
# 20  Institutul de Genetică, Fiziologie și Protecți...
# 21               Institutul de Patrimoniului Cultural
# 22  Institutul de Filologie Română ”Bogdan Petrice...
# 23  Institutul de Cercetări Juridice, Politice și ...
# 24                              Institutul de Istorie
# 25         Institutul Național de Cercetări Economice
# 26  Institutul de Dezvoltare a Societății Informaț...
# 27  Grădina Botanică Națională (institut) ”Alexand...
# 28    Bibliteca Științifică (institut) ”Andrei Lupan”
# 29  Muzeul Național de Etnografie și Istorie Naturală
# 30              Muzeul Național de Istorie a Moldovei
# 31                               Institutul Oncologic
# 32                      Institutul Mamei și Copilului
# 33            Institutul Neurologie și Neurochirurgie
# 34                          Institutul de Cardiologie
# 35  Institutul de Ftiziopneumologie ” Chiril Draga...
# 36                     Institutul de Medicină Urgentă
# 37                         Spitalul Clinic Republican
# 38              Agenția Națională de Sănătate Publică
# 39  Universitatea de Stat de Medicină ”Nicolae Tes...
# 40           Universitatea Agrară de Stat din Moldova
# 41           Institutul de Tehnică Agricolă ”Mecagro”
# 42  Institutul de Cercetări pentru Culturile de Câ...
# 43               Institutul de Fitotehnie ”Porumbeni”
# 44  Institutul de Pedologie, Agrochimie și Protecț...
# 45                    Academia de Administare publică
#
#                                           url                    domain
# 0                              http://usm.md/                    usm.md
# 1                     https://www.upsc.md/en/                   upsc.md
# 2                            http://usarb.md/                  usarb.md
# 3                        http://www.usefs.md/                  usefs.md
# 4                        http://edu.asm.md/md                edu.asm.md
# 5                      http://www.uccm.md/en/                   uccm.md
# 6                             https://utm.md/                    utm.md
# 7                       http://www.ase.md/ro/                    ase.md
# 8                            http://amtap.md/                  amtap.md
# 9                          http://www.ise.md/                    ise.md
# 10                        http://chem.asm.md/               chem.asm.md
# 11                        http://www.math.md/                   math.md
# 12                   https://www.phys.asm.md/               phys.asm.md
# 13                         http://igs.asm.md/                igs.asm.md
# 14                 http://www.zoology.asm.md/            zoology.asm.md
# 15                     http://www.ieg.asm.md/                ieg.asm.md
# 16                        http://nano.asm.md/               nano.asm.md
# 17                      http://www.ie.asm.md/                 ie.asm.md
# 18                     http://www.ifs.asm.md/                ifs.asm.md
# 19                     http://www.imb.asm.md/                imb.asm.md
# 20                       http://igfpp.asm.md/              igfpp.asm.md
# 21                  http://patrimoniu.asm.md/         patrimoniu.asm.md
# 22                      http://www.if.asm.md/                 if.asm.md
# 23                        http://icjp.asm.md/               icjp.asm.md
# 24                 http://www.history.asm.md/            history.asm.md
# 25                       https://www.ince.md/                   ince.md
# 26                           https://idsi.md/                   idsi.md
# 27         http://www.gradinabotanica.asm.md/    gradinabotanica.asm.md
# 28                    http://bsclupan.asm.md/           bsclupan.asm.md
# 29                       http://www.muzeu.md/                  muzeu.md
# 30          https://www.nationalmuseum.md/ro/         nationalmuseum.md
# 31                            http://onco.md/                   onco.md
# 32               https://www.mama-copilul.md/           mama-copilul.md
# 33                             http://inn.md/                    inn.md
# 34                    http://icardiologie.md/           icardiologie.md
# 35           http://ftiziopneumologie.asm.md/  ftiziopneumologie.asm.md
# 36                     http://www.urgenta.md/                urgenta.md
# 37                         http://www.scr.md/                    scr.md
# 38                            http://ansp.md/                   ansp.md
# 39                         http://usmf.md/en/                   usmf.md
# 40                        http://www.uasm.md/                   uasm.md
# 41         http://mecagro.md/ro/credit-tehnic                mecagro.md
# 42  http://agriculture.cia.md/fito/index.html        agriculture.cia.md
# 43                       http://porumbeni.md/              porumbeni.md
# 44                  http://www.ipaps.md/home/                  ipaps.md
# 45                         http://aap.gov.md/                aap.gov.md

# %% [markdown]
# ## Notes
# - Filtering keeps only domains ending in `.md` or `.ro`.
# - If the ANCD pages change structure, you can tweak the simple heuristics:
#   - For incubators/parks, we grab the nearest list item text before “Pagina web”.
#   - For research organizations, we read the 2nd column as the name and the next column with a link as the website.
# - The CSVs are saved next to this notebook as:
#   - `innovation_incubators_parks_md_ro.csv`
#   - `research_organizations_md_ro.csv`
