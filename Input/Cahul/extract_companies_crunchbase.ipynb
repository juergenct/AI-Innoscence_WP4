# %%
import pandas as pd

# %%
df_organizations = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/CrunchBase Dump TUHH/organizations.csv')

# %%
# Filter df_organizations for entries where 'country_code' is 'MDA'
df_organizations = df_organizations[df_organizations['country_code'] == "MDA"]

# %%
df_organizations['city'].value_counts()
# Out:
# city
# Chisinau        236
# Kishinëv          5
# Tiraspol          2
# Balti             2
# Cantemir          1
# Copaceni          1
# Orhei             1
# Sîngera           1
# Gura Bîcului      1
# Stauceni          1
# Centru            1
# Straseni          1
# Varnita           1
# Magdacesti        1
# Name: count, dtype: int64

# %%
df_investors = pd.read_csv('/mnt/hdd02/Projekt_EDV_TEK/CrunchBase Dump TUHH/investors.csv')

# %%
# Filter df_investors for entries where 'country_code' is 'MDA'
df_investors = df_investors[df_investors['country_code'] == "MDA"]

# %%
df_investors['city'].value_counts()
# Out:
# city
# Chisinau    4
# Name: count, dtype: int64
