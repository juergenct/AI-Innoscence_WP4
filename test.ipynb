# %%
import pandas as pd

# %%
df_verified_results = pd.read_csv('CE-Ecosystem Builder/hamburg_ce_ecosystem/data/verified/verification_results.csv')

# %%
df_verified_results.head()
# Out:
#                                                  url  is_hamburg_based  \
# 0                          https://www.kale-trans.de              True
# 1  https://www.brillux.de/unternehmen/niederlassu...             False
# 2  https://belepes-regisztracio.hu/facebook/faceb...             False
# 3  http://www.atco.de/kategorie/Logistik-_-AECO,6...              True
# 4                           https://www.germagmbh.de              True
#
#    hamburg_confidence  is_ce_related  ce_confidence  \
# 0                 0.8          False            0.0
# 1                 0.0          False            0.0
# 2                 0.0          False            0.0
# 3                 1.0          False            0.0
# 4                 1.0          False            0.0
#
#                               verification_reasoning  should_extract
# 0  Hamburg: +49 40 / 533 99 99, +49 40 / 533 91 5...           False
# 1                                   Hamburg:  | CE:            False
# ...

# %%
# Drop column input_category
df_verified_results = df_verified_results.drop(columns=['input_category'])

# %%
len(df_verified_results)
# Out:
# 18574

# %%
df_verified_results['should_extract'].value_counts()
# Out:
# should_extract
# False    16254
# True      2320
# Name: count, dtype: int64

# %%
df_verified_results.to_csv('verified_results_hamburg_ce_ecosystem.csv', index=False)
